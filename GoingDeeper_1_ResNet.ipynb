# %% [markdown]
# # ResNet 개요
# - VGG이후 Network를 깊게 하는 것에 대한 연구가 진행. 하지만, Network의 깊이가 깊어질수록 성능이 저하되는 문제점이 존재.
#     - Vanishing Gradient
#     - 최적으로 loss 감소가 이루어지지 않음(수렴이 아닌 발산)
#
# - ResNet의 주요 특징
#     - Shortcut
#         - 이전 레이어의 출력값을 conv layer를 거치지 않고 전달
#     - Identity block

# %%
from tensorflow.keras.layers import Input, Conv2D, Dense, BatchNormalization, Activation, ZeroPadding2D, MaxPooling2D, Dropout, GlobalAveragePooling2D, Add
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam , RMSprop
from tensorflow.keras.utils import to_categorical, Sequence
from sklearn.model_selection import train_test_split
from tensorflow.keras.datasets import cifar10
import sklearn
import numpy as np
import cv2
import os
import pandas as pd

# %% [markdown]
# ## Identity_block_34 구현하기

# %%
# ResNet34 identity block 구현하기

def identity_block_34(input_tensor, middle_kernel_size, filters, stage, block):
    
    filter1, filter2 = filters

    # 레이어 이름설정
    conv_name = 'res_s' + str(stage) + '_b' + str(block) + '_branch_'
    bn_name = 'bn_s'+ str(stage) + '_b' + str(block) + '_branch_'

    # 1번째 conv
    x = Conv2D(filters=filter1, kernel_size=middle_kernel_size, padding='same', kernel_initializer='he_normal', name=conv_name+'a')(input_tensor)
    x = BatchNormalization(axis=3, name=bn_name+'a')(x)
    x = Activation('relu')(x)

    # 2번째 conv
    x = Conv2D(filters=filter2, kernel_size=middle_kernel_size, padding='same', kernel_initializer='he_normal', name=conv_name+'b')(x)
    x = BatchNormalization(axis=3, name=bn_name+'b')(x)
    x = Activation('relu')(x)

    # Add
    x = Add()([input_tensor, x])
    x = Activation('relu')(x)

    return x

# %%
# identity_block_34 실습

input_tensor = Input(shape=(56,56,64), name='test_input')
x = identity_block_34(input_tensor, middle_kernel_size=3, filters = [64,64], stage=2, block=1)
output = identity_block_34(x, middle_kernel_size=3, filters = [64,64], stage=2, block=2)
identity_layers = Model(inputs=input_tensor, outputs=output)
identity_layers.summary()

# __init__() missing 1 required positional argument: 'filters' => filters를 잘못씀
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  test_input (InputLayer)        [(None, 56, 56, 64)  0           []
#                                 ]
#
#  res_s2_b1_branch_a (Conv2D)    (None, 56, 56, 64)   36928       ['test_input[0][0]']
#
#  bn_s2_b1_branch_a (BatchNormal  (None, 56, 56, 64)  256         ['res_s2_b1_branch_a[0][0]']
#  ization)
#
#  activation (Activation)        (None, 56, 56, 64)   0           ['bn_s2_b1_branch_a[0][0]']
#
#  res_s2_b1_branch_b (Conv2D)    (None, 56, 56, 64)   36928       ['activation[0][0]']
#
#  bn_s2_b1_branch_b (BatchNormal  (None, 56, 56, 64)  256         ['res_s2_b1_branch_b[0][0]']
#  ization)
#
#  activation_1 (Activation)      (None, 56, 56, 64)   0           ['bn_s2_b1_branch_b[0][0]']
#
#  add (Add)                      (None, 56, 56, 64)   0           ['test_input[0][0]',
#                                                                   'activation_1[0][0]']
#
#  activation_2 (Activation)      (None, 56, 56, 64)   0           ['add[0][0]']
#
#  res_s2_b2_branch_a (Conv2D)    (None, 56, 56, 64)   36928       ['activation_2[0][0]']
#
#  bn_s2_b2_branch_a (BatchNormal  (None, 56, 56, 64)  256         ['res_s2_b2_branch_a[0][0]']
#  ization)
#
#  activation_3 (Activation)      (None, 56, 56, 64)   0           ['bn_s2_b2_branch_a[0][0]']
#
#  res_s2_b2_branch_b (Conv2D)    (None, 56, 56, 64)   36928       ['activation_3[0][0]']
#
#  bn_s2_b2_branch_b (BatchNormal  (None, 56, 56, 64)  256         ['res_s2_b2_branch_b[0][0]']
#  ization)
#
#  activation_4 (Activation)      (None, 56, 56, 64)   0           ['bn_s2_b2_branch_b[0][0]']
#
#  add_1 (Add)                    (None, 56, 56, 64)   0           ['activation_2[0][0]',
#                                                                   'activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 56, 56, 64)   0           ['add_1[0][0]']
#
# ==================================================================================================
# Total params: 148,736
# Trainable params: 148,224
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %% [markdown]
# ## identity_block_50 구현하기

# %%
# ResNet50 identity block 구현하기

def identity_block_50(input_tensor, middle_kernel_size, filters, stage, block):

    filter1, filter2, filter3 = filters
    
    # 레이어 이름설정
    conv_name = 'res_s' + str(stage) + '_b' + str(block) + '_branch_'
    bn_name = 'bn_s'+ str(stage) + '_b' + str(block) + '_branch_'

    # 1번째 Conv
    x = Conv2D(filters=filter1, kernel_size=(1,1), kernel_initializer='he_normal', name=conv_name+'a')(input_tensor)
    x = BatchNormalization(axis=3, name=bn_name+'a')(x)
    x = Activation('relu')(x)

    # 2번째 Conv
    x = Conv2D(filters=filter2, kernel_size=middle_kernel_size, padding='same', kernel_initializer='he_normal', name=conv_name+'b')(x)
    x = BatchNormalization(axis=3, name=bn_name+'b')(x)
    x = Activation('relu')(x)

    # 3번째 Conv
    x = Conv2D(filters=filter3, kernel_size=(1,1), kernel_initializer='he_normal', name=conv_name+'c')(x)
    x = BatchNormalization(axis=3, name=bn_name+'c')(x)
    
    # Add
    x = Add()([input_tensor, x])
    x = Activation('relu')(x)

    return x

# %%
# identity_block_50 실습
input_tensor = Input(shape=(56,56,256), name='test_input')
x = identity_block_50(input_tensor, middle_kernel_size=(3,3), filters=[64,64,256], stage=2, block='1')
x = identity_block_50(x, middle_kernel_size=(3,3), filters=[64,64,256], stage=2, block='2')
output = identity_block_50(x, middle_kernel_size=(3,3), filters=[64,64,256], stage=2, block='3')
identity_layers = Model(inputs=input_tensor, outputs=output)
identity_layers.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  test_input (InputLayer)        [(None, 56, 56, 256  0           []
#                                 )]
#
#  res_s2_b1_branch_a (Conv2D)    (None, 56, 56, 64)   16448       ['test_input[0][0]']
#
#  bn_s2_b1_branch_a (BatchNormal  (None, 56, 56, 64)  256         ['res_s2_b1_branch_a[0][0]']
#  ization)
#
#  activation_6 (Activation)      (None, 56, 56, 64)   0           ['bn_s2_b1_branch_a[0][0]']
#
#  res_s2_b1_branch_b (Conv2D)    (None, 56, 56, 64)   36928       ['activation_6[0][0]']
#
#  bn_s2_b1_branch_b (BatchNormal  (None, 56, 56, 64)  256         ['res_s2_b1_branch_b[0][0]']
#  ization)
#
#  activation_7 (Activation)      (None, 56, 56, 64)   0           ['bn_s2_b1_branch_b[0][0]']
#
#  res_s2_b1_branch_c (Conv2D)    (None, 56, 56, 256)  16640       ['activation_7[0][0]']
#
#  bn_s2_b1_branch_c (BatchNormal  (None, 56, 56, 256)  1024       ['res_s2_b1_branch_c[0][0]']
#  ization)
#
#  add_2 (Add)                    (None, 56, 56, 256)  0           ['test_input[0][0]',
#                                                                   'bn_s2_b1_branch_c[0][0]']
#
#  activation_8 (Activation)      (None, 56, 56, 256)  0           ['add_2[0][0]']
#
#  res_s2_b2_branch_a (Conv2D)    (None, 56, 56, 64)   16448       ['activation_8[0][0]']
#
#  bn_s2_b2_branch_a (BatchNormal  (None, 56, 56, 64)  256         ['res_s2_b2_branch_a[0][0]']
#  ization)
#
#  activation_9 (Activation)      (None, 56, 56, 64)   0           ['bn_s2_b2_branch_a[0][0]']
#
#  res_s2_b2_branch_b (Conv2D)    (None, 56, 56, 64)   36928       ['activation_9[0][0]']
#
#  bn_s2_b2_branch_b (BatchNormal  (None, 56, 56, 64)  256         ['res_s2_b2_branch_b[0][0]']
#  ization)
#
#  activation_10 (Activation)     (None, 56, 56, 64)   0           ['bn_s2_b2_branch_b[0][0]']
#
#  res_s2_b2_branch_c (Conv2D)    (None, 56, 56, 256)  16640       ['activation_10[0][0]']
#
#  bn_s2_b2_branch_c (BatchNormal  (None, 56, 56, 256)  1024       ['res_s2_b2_branch_c[0][0]']
#  ization)
#
#  add_3 (Add)                    (None, 56, 56, 256)  0           ['activation_8[0][0]',
#                                                                   'bn_s2_b2_branch_c[0][0]']
#
#  activation_11 (Activation)     (None, 56, 56, 256)  0           ['add_3[0][0]']
#
#  res_s2_b3_branch_a (Conv2D)    (None, 56, 56, 64)   16448       ['activation_11[0][0]']
#
#  bn_s2_b3_branch_a (BatchNormal  (None, 56, 56, 64)  256         ['res_s2_b3_branch_a[0][0]']
#  ization)
#
#  activation_12 (Activation)     (None, 56, 56, 64)   0           ['bn_s2_b3_branch_a[0][0]']
#
#  res_s2_b3_branch_b (Conv2D)    (None, 56, 56, 64)   36928       ['activation_12[0][0]']
#
#  bn_s2_b3_branch_b (BatchNormal  (None, 56, 56, 64)  256         ['res_s2_b3_branch_b[0][0]']
#  ization)
#
#  activation_13 (Activation)     (None, 56, 56, 64)   0           ['bn_s2_b3_branch_b[0][0]']
#
#  res_s2_b3_branch_c (Conv2D)    (None, 56, 56, 256)  16640       ['activation_13[0][0]']
#
#  bn_s2_b3_branch_c (BatchNormal  (None, 56, 56, 256)  1024       ['res_s2_b3_branch_c[0][0]']
#  ization)
#
#  add_4 (Add)                    (None, 56, 56, 256)  0           ['activation_11[0][0]',
#                                                                   'bn_s2_b3_branch_c[0][0]']
#
#  activation_14 (Activation)     (None, 56, 56, 256)  0           ['add_4[0][0]']
#
# ==================================================================================================
# Total params: 214,656
# Trainable params: 212,352
# Non-trainable params: 2,304
# __________________________________________________________________________________________________

# %% [markdown]
# ## reduce_block_34 구현하기
# - feature map의 크기를 절반으로 줄이는 block 구현
# - feature map의 사이즈를 맞추기 위해 zeropadding 설정

# %%
def reduce_block_34(input_tensor, middle_kernel_size, filters, stage, block, strides=(2,2)):

    filter1, filter2 = filters

    conv_name = 'res_s' + str(stage) + '_b' + str(block) + '_branch_'
    bn_name = 'bn_s'+ str(stage) + '_b' + str(block) + '_branch_'

    # 첫번째 conv(feature map의 사이즈를 절반으로 줄임.)
    x = ZeroPadding2D(padding=(1,1), name=conv_name+'padding')(input_tensor) # zeropadding을 하지 않을 경우 사이즈를 줄인 결과값이 (27,27)로 나온다
    x = Conv2D(filters=filter1, kernel_size=(3,3), strides=(2,2), kernel_initializer='he_normal', name=conv_name+'a')(x)
    x = BatchNormalization(axis=3, name=bn_name+'a')(x)
    x = Activation('relu')(x)

    # 두번째 conv
    x = Conv2D(filters=filter2, kernel_size=middle_kernel_size, padding='same', kernel_initializer='he_normal', name=conv_name+'b')(x)
    x = BatchNormalization(axis=3, name=bn_name+'b')(x)
    
    # shortcut
    shortcut = Conv2D(filters=filter2, kernel_size=(1,1), strides=strides, kernel_initializer='he_normal', name=conv_name+'shortcut')(input_tensor)
    shortcut = BatchNormalization(axis=3, name=bn_name+'shortcut')(x)

    # ADD
    shortcut = Add()([x, shortcut])
    x = Activation('relu')(x)

    return x

# %%
# reduce_block_34 실습

input_tensor = Input(shape=[56,56,128], name='input_test')
x = reduce_block_34(input_tensor, middle_kernel_size=3, filters=[128,128], stage=2, block=1)
output = identity_block_34(x, middle_kernel_size=3, filters=[128,128], stage=2, block=2)
identity_layers = Model(inputs=input_tensor, outputs=output)
identity_layers.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_test (InputLayer)        [(None, 56, 56, 128  0           []
#                                 )]
#
#  res_s2_b1_branch_padding (Zero  (None, 58, 58, 128)  0          ['input_test[0][0]']
#  Padding2D)
#
#  res_s2_b1_branch_a (Conv2D)    (None, 28, 28, 128)  147584      ['res_s2_b1_branch_padding[0][0]'
#                                                                  ]
#
#  bn_s2_b1_branch_a (BatchNormal  (None, 28, 28, 128)  512        ['res_s2_b1_branch_a[0][0]']
#  ization)
#
#  activation_15 (Activation)     (None, 28, 28, 128)  0           ['bn_s2_b1_branch_a[0][0]']
#
#  res_s2_b1_branch_b (Conv2D)    (None, 28, 28, 128)  147584      ['activation_15[0][0]']
#
#  bn_s2_b1_branch_b (BatchNormal  (None, 28, 28, 128)  512        ['res_s2_b1_branch_b[0][0]']
#  ization)
#
#  activation_16 (Activation)     (None, 28, 28, 128)  0           ['bn_s2_b1_branch_b[0][0]']
#
#  res_s2_b2_branch_a (Conv2D)    (None, 28, 28, 128)  147584      ['activation_16[0][0]']
#
#  bn_s2_b2_branch_a (BatchNormal  (None, 28, 28, 128)  512        ['res_s2_b2_branch_a[0][0]']
#  ization)
#
#  activation_17 (Activation)     (None, 28, 28, 128)  0           ['bn_s2_b2_branch_a[0][0]']
#
#  res_s2_b2_branch_b (Conv2D)    (None, 28, 28, 128)  147584      ['activation_17[0][0]']
#
#  bn_s2_b2_branch_b (BatchNormal  (None, 28, 28, 128)  512        ['res_s2_b2_branch_b[0][0]']
#  ization)
#
#  activation_18 (Activation)     (None, 28, 28, 128)  0           ['bn_s2_b2_branch_b[0][0]']
#
#  add_6 (Add)                    (None, 28, 28, 128)  0           ['activation_16[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_19 (Activation)     (None, 28, 28, 128)  0           ['add_6[0][0]']
#
# ==================================================================================================
# Total params: 592,384
# Trainable params: 591,360
# Non-trainable params: 1,024
# __________________________________________________________________________________________________

# %% [markdown]
# ## reduce_block_50 구현하기
# - feature map의 사이즈를 절반으로 줄이는 block 구현
# - feature map의 사이즈가 절반으로 줄어드는 stage의 첫번째 block으로 사용

# %%
# feature map의 크기를 절반으로 줄이는 reduce_block()만들기

def reduce_block_50(input_tensor, middle_kernel_size, filters, stage, block, strides=(2,2)):
    
    filter1, filter2, filter3 = filters

    conv_name = 'res_s' + str(stage) + '_b' + str(block) + '_branch_'
    bn_name = 'bn_s'+ str(stage) + '_b' + str(block) + '_branch_'

    # 첫번째 conv (feature map의 크기를 절반으로 줄임. 첫번째 stage에서는 예외.)
    x = Conv2D(filters=filter1, kernel_size=(1,1), strides=strides, kernel_initializer='he_normal', name=conv_name+'1')(input_tensor)
    x = BatchNormalization(axis=3, name=bn_name+'a')(x)
    x = Activation('relu')(x)

    # 두번째 conv
    x = Conv2D(filters=filter2, kernel_size=middle_kernel_size, padding='same', kernel_initializer='he_normal', name=conv_name+'2')(x)
    x = BatchNormalization(axis=3, name=bn_name+'b')(x)
    x = Activation('relu')(x)

    # 세번째 conv
    x = Conv2D(filters=filter3, kernel_size=(1,1), kernel_initializer='he_normal', name=conv_name+'3')(x)
    x = BatchNormalization(axis=3, name=bn_name+'c')(x)
    
    # shortcut 
    shortcut = Conv2D(filters=filter3, kernel_size=(1,1), strides=strides, kernel_initializer='he_normal', name = conv_name+'shortcut')(input_tensor)
    shortcut = BatchNormalization(axis=3, name=bn_name+'shortcut')(shortcut)

    # ADD
    x = Add()([x, shortcut])
    x = Activation('relu')(x)

    return x

# %%
# reduce_block 실습

input_tensor = Input(shape=(56,56,256), name='test_input')
x = reduce_block_50(input_tensor, middle_kernel_size=(3,3), filters=[64,64,256], stage=2, block=1, strides=(2,2))
x = identity_block_50(x, middle_kernel_size=3, filters=[64,64,256], stage=2, block=2)
output = identity_block_50(x, middle_kernel_size=3, filters=[64,64,256], stage=2, block=3)
identity_layers = Model(inputs=input_tensor, outputs=output)
identity_layers.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  test_input (InputLayer)        [(None, 56, 56, 256  0           []
#                                 )]
#
#  res_s2_b1_branch_1 (Conv2D)    (None, 28, 28, 64)   16448       ['test_input[0][0]']
#
#  bn_s2_b1_branch_a (BatchNormal  (None, 28, 28, 64)  256         ['res_s2_b1_branch_1[0][0]']
#  ization)
#
#  activation_20 (Activation)     (None, 28, 28, 64)   0           ['bn_s2_b1_branch_a[0][0]']
#
#  res_s2_b1_branch_2 (Conv2D)    (None, 28, 28, 64)   36928       ['activation_20[0][0]']
#
#  bn_s2_b1_branch_b (BatchNormal  (None, 28, 28, 64)  256         ['res_s2_b1_branch_2[0][0]']
#  ization)
#
#  activation_21 (Activation)     (None, 28, 28, 64)   0           ['bn_s2_b1_branch_b[0][0]']
#
#  res_s2_b1_branch_3 (Conv2D)    (None, 28, 28, 256)  16640       ['activation_21[0][0]']
#
#  res_s2_b1_branch_shortcut (Con  (None, 28, 28, 256)  65792      ['test_input[0][0]']
#  v2D)
#
#  bn_s2_b1_branch_c (BatchNormal  (None, 28, 28, 256)  1024       ['res_s2_b1_branch_3[0][0]']
#  ization)
#
#  bn_s2_b1_branch_shortcut (Batc  (None, 28, 28, 256)  1024       ['res_s2_b1_branch_shortcut[0][0]
#  hNormalization)                                                 ']
#
#  add_7 (Add)                    (None, 28, 28, 256)  0           ['bn_s2_b1_branch_c[0][0]',
#                                                                   'bn_s2_b1_branch_shortcut[0][0]'
#                                                                  ]
#
#  activation_22 (Activation)     (None, 28, 28, 256)  0           ['add_7[0][0]']
#
#  res_s2_b2_branch_a (Conv2D)    (None, 28, 28, 64)   16448       ['activation_22[0][0]']
#
#  bn_s2_b2_branch_a (BatchNormal  (None, 28, 28, 64)  256         ['res_s2_b2_branch_a[0][0]']
#  ization)
#
#  activation_23 (Activation)     (None, 28, 28, 64)   0           ['bn_s2_b2_branch_a[0][0]']
#
#  res_s2_b2_branch_b (Conv2D)    (None, 28, 28, 64)   36928       ['activation_23[0][0]']
#
#  bn_s2_b2_branch_b (BatchNormal  (None, 28, 28, 64)  256         ['res_s2_b2_branch_b[0][0]']
#  ization)
#
#  activation_24 (Activation)     (None, 28, 28, 64)   0           ['bn_s2_b2_branch_b[0][0]']
#
#  res_s2_b2_branch_c (Conv2D)    (None, 28, 28, 256)  16640       ['activation_24[0][0]']
#
#  bn_s2_b2_branch_c (BatchNormal  (None, 28, 28, 256)  1024       ['res_s2_b2_branch_c[0][0]']
#  ization)
#
#  add_8 (Add)                    (None, 28, 28, 256)  0           ['activation_22[0][0]',
#                                                                   'bn_s2_b2_branch_c[0][0]']
#
#  activation_25 (Activation)     (None, 28, 28, 256)  0           ['add_8[0][0]']
#
#  res_s2_b3_branch_a (Conv2D)    (None, 28, 28, 64)   16448       ['activation_25[0][0]']
#
#  bn_s2_b3_branch_a (BatchNormal  (None, 28, 28, 64)  256         ['res_s2_b3_branch_a[0][0]']
#  ization)
#
#  activation_26 (Activation)     (None, 28, 28, 64)   0           ['bn_s2_b3_branch_a[0][0]']
#
#  res_s2_b3_branch_b (Conv2D)    (None, 28, 28, 64)   36928       ['activation_26[0][0]']
#
#  bn_s2_b3_branch_b (BatchNormal  (None, 28, 28, 64)  256         ['res_s2_b3_branch_b[0][0]']
#  ization)
#
#  activation_27 (Activation)     (None, 28, 28, 64)   0           ['bn_s2_b3_branch_b[0][0]']
#
#  res_s2_b3_branch_c (Conv2D)    (None, 28, 28, 256)  16640       ['activation_27[0][0]']
#
#  bn_s2_b3_branch_c (BatchNormal  (None, 28, 28, 256)  1024       ['res_s2_b3_branch_c[0][0]']
#  ization)
#
#  add_9 (Add)                    (None, 28, 28, 256)  0           ['activation_25[0][0]',
#                                                                   'bn_s2_b3_branch_c[0][0]']
#
#  activation_28 (Activation)     (None, 28, 28, 256)  0           ['add_9[0][0]']
#
# ==================================================================================================
# Total params: 281,472
# Trainable params: 278,656
# Non-trainable params: 2,816
# __________________________________________________________________________________________________

# %% [markdown]
# ## 첫번째 stage 구현

# %%
# stage1 구현
# input image에 7x7 conv, strides = 2, filters = 64
# 3x3 maxpooling, strides = 2


def first_conv(input_tensor):

    x = ZeroPadding2D(padding=(3,3), name='conv1_pad')(input_tensor)
    x = Conv2D(filters=64, kernel_size=(7,7), strides=2, padding = 'valid', kernel_initializer='he_normal', name='conv1')(x)
    x = BatchNormalization(axis=3, name='conv1_nm')(x)
    x = Activation('relu')(x)

    x = ZeroPadding2D(padding=(1,1), name='pool1')(x)
    x = MaxPooling2D(pool_size=(3,3), strides=2)(x)

    return x

# %%
input_tensor=Input(shape=(224,224,3), name='test_input')
output = first_conv(input_tensor)

model = Model(inputs=input_tensor, outputs = output)
model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  test_input (InputLayer)     [(None, 224, 224, 3)]     0
#
#  conv1_pad (ZeroPadding2D)   (None, 230, 230, 3)       0
#
#  conv1 (Conv2D)              (None, 112, 112, 64)      9472
#
#  conv1_nm (BatchNormalizatio  (None, 112, 112, 64)     256
#  n)
#
#  activation_29 (Activation)  (None, 112, 112, 64)      0
#
#  pool1 (ZeroPadding2D)       (None, 114, 114, 64)      0
#
#  max_pooling2d (MaxPooling2D  (None, 56, 56, 64)       0
#  )
#
# =================================================================
# Total params: 9,728
# Trainable params: 9,600
# Non-trainable params: 128
# _________________________________________________________________

# %%
# first_conv 실습
# 주의할 점! 
# first_conv의 결과값(= (56,56,64)), identity_block의 결과값(= (56,56,256))
# 채널수가 다르기 때문에 연산을 할 수 없다. 
# first_conv의 결과값을 (56,56,64) -> (56,56,256)으로 변환하여 더해야 한다.=> 따라서, 첫번째 블록으로는 identity_block이 아닌 reduce_block을 사용.

input_tensor=Input(shape=(224,224,3), name='test_input')
x = first_conv(input_tensor)
# output = identity_block_50(x, middle_kernel_size=(3,3), filters=[64,64,256], stage=2, block=1)
output = reduce_block_50(x, 3, filters=[64,64,256], stage=2, block=1, strides=(1,1))


model = Model(inputs=input_tensor, outputs = output)
model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  test_input (InputLayer)        [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['test_input[0][0]']
#
#  conv1 (Conv2D)                 (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_nm (BatchNormalization)  (None, 112, 112, 64  256         ['conv1[0][0]']
#                                 )
#
#  activation_30 (Activation)     (None, 112, 112, 64  0           ['conv1_nm[0][0]']
#                                 )
#
#  pool1 (ZeroPadding2D)          (None, 114, 114, 64  0           ['activation_30[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)  0           ['pool1[0][0]']
#
#  res_s2_b1_branch_1 (Conv2D)    (None, 56, 56, 64)   4160        ['max_pooling2d_1[0][0]']
#
#  bn_s2_b1_branch_a (BatchNormal  (None, 56, 56, 64)  256         ['res_s2_b1_branch_1[0][0]']
#  ization)
#
#  activation_31 (Activation)     (None, 56, 56, 64)   0           ['bn_s2_b1_branch_a[0][0]']
#
#  res_s2_b1_branch_2 (Conv2D)    (None, 56, 56, 64)   36928       ['activation_31[0][0]']
#
#  bn_s2_b1_branch_b (BatchNormal  (None, 56, 56, 64)  256         ['res_s2_b1_branch_2[0][0]']
#  ization)
#
#  activation_32 (Activation)     (None, 56, 56, 64)   0           ['bn_s2_b1_branch_b[0][0]']
#
#  res_s2_b1_branch_3 (Conv2D)    (None, 56, 56, 256)  16640       ['activation_32[0][0]']
#
#  res_s2_b1_branch_shortcut (Con  (None, 56, 56, 256)  16640      ['max_pooling2d_1[0][0]']
#  v2D)
#
#  bn_s2_b1_branch_c (BatchNormal  (None, 56, 56, 256)  1024       ['res_s2_b1_branch_3[0][0]']
#  ization)
#
#  bn_s2_b1_branch_shortcut (Batc  (None, 56, 56, 256)  1024       ['res_s2_b1_branch_shortcut[0][0]
#  hNormalization)                                                 ']
#
#  add_10 (Add)                   (None, 56, 56, 256)  0           ['bn_s2_b1_branch_c[0][0]',
#                                                                   'bn_s2_b1_branch_shortcut[0][0]'
#                                                                  ]
#
#  activation_33 (Activation)     (None, 56, 56, 256)  0           ['add_10[0][0]']
#
# ==================================================================================================
# Total params: 86,656
# Trainable params: 85,248
# Non-trainable params: 1,408
# __________________________________________________________________________________________________

# %% [markdown]
# ## ResNet34 구현하기

# %%
def create_resnet_34(shape=(224,224,3)):
    input_tensor = Input(shape = shape)

    # 첫번째 stage
    x = first_conv(input_tensor)

    # 두번째 stage
    x = identity_block_34(x, middle_kernel_size=3, filters=[64,64], stage=2, block=1)
    x = identity_block_34(x, middle_kernel_size=3, filters=[64,64], stage=2, block=2)
    x = identity_block_34(x, middle_kernel_size=3, filters=[64,64], stage=2, block=3)

    # 세번째 stage
    x = reduce_block_34(x, middle_kernel_size=3, filters=[128,128], stage=3, block=1)
    x = identity_block_34(x, middle_kernel_size=3, filters=[128,128], stage=3, block=2)
    x = identity_block_34(x, middle_kernel_size=3, filters=[128,128], stage=3, block=3)
    x = identity_block_34(x, middle_kernel_size=3, filters=[128,128], stage=3, block=4)

    # 네번째 stage
    x = reduce_block_34(x, middle_kernel_size=3, filters=[256,256], stage=4, block=1)
    x = identity_block_34(x, middle_kernel_size=3, filters=[256,256], stage=4, block=2)
    x = identity_block_34(x, middle_kernel_size=3, filters=[256,256], stage=4, block=3)
    x = identity_block_34(x, middle_kernel_size=3, filters=[256,256], stage=4, block=4)
    x = identity_block_34(x, middle_kernel_size=3, filters=[256,256], stage=4, block=5)
    x = identity_block_34(x, middle_kernel_size=3, filters=[256,256], stage=4, block=6)

    # 다섯번째 stage
    x = reduce_block_34(x, middle_kernel_size=3, filters=[512,512], stage=5, block=1)
    x = identity_block_34(x, middle_kernel_size=3, filters=[512,512], stage=5, block=2)
    x = identity_block_34(x, middle_kernel_size=3, filters=[512,512], stage=5, block=3)    

    # fc layer
    x = GlobalAveragePooling2D(name='GAP')(x)
    x = Dropout(rate=0.5)(x)
    x = Dense(200, activation='relu', name='fc1')(x)
    x = Dropout(rate=0.5)(x)
    output = Dense(10, activation='softmax', name='output')(x)

    model = Model(inputs=input_tensor, outputs=output)
    model.summary()

    return model

# %%
model_34 = create_resnet_34(shape=(224,224,3))
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_1[0][0]']
#
#  conv1 (Conv2D)                 (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_nm (BatchNormalization)  (None, 112, 112, 64  256         ['conv1[0][0]']
#                                 )
#
#  activation_34 (Activation)     (None, 112, 112, 64  0           ['conv1_nm[0][0]']
#                                 )
#
#  pool1 (ZeroPadding2D)          (None, 114, 114, 64  0           ['activation_34[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 56, 56, 64)  0           ['pool1[0][0]']
#
#  res_s2_b1_branch_a (Conv2D)    (None, 56, 56, 64)   36928       ['max_pooling2d_2[0][0]']
#
#  bn_s2_b1_branch_a (BatchNormal  (None, 56, 56, 64)  256         ['res_s2_b1_branch_a[0][0]']
#  ization)
#
#  activation_35 (Activation)     (None, 56, 56, 64)   0           ['bn_s2_b1_branch_a[0][0]']
#
#  res_s2_b1_branch_b (Conv2D)    (None, 56, 56, 64)   36928       ['activation_35[0][0]']
#
#  bn_s2_b1_branch_b (BatchNormal  (None, 56, 56, 64)  256         ['res_s2_b1_branch_b[0][0]']
#  ization)
#
#  activation_36 (Activation)     (None, 56, 56, 64)   0           ['bn_s2_b1_branch_b[0][0]']
#
#  add_11 (Add)                   (None, 56, 56, 64)   0           ['max_pooling2d_2[0][0]',
#                                                                   'activation_36[0][0]']
#
#  activation_37 (Activation)     (None, 56, 56, 64)   0           ['add_11[0][0]']
#
#  res_s2_b2_branch_a (Conv2D)    (None, 56, 56, 64)   36928       ['activation_37[0][0]']
#
#  bn_s2_b2_branch_a (BatchNormal  (None, 56, 56, 64)  256         ['res_s2_b2_branch_a[0][0]']
#  ization)
#
#  activation_38 (Activation)     (None, 56, 56, 64)   0           ['bn_s2_b2_branch_a[0][0]']
#
#  res_s2_b2_branch_b (Conv2D)    (None, 56, 56, 64)   36928       ['activation_38[0][0]']
#
#  bn_s2_b2_branch_b (BatchNormal  (None, 56, 56, 64)  256         ['res_s2_b2_branch_b[0][0]']
#  ization)
#
#  activation_39 (Activation)     (None, 56, 56, 64)   0           ['bn_s2_b2_branch_b[0][0]']
#
#  add_12 (Add)                   (None, 56, 56, 64)   0           ['activation_37[0][0]',
#                                                                   'activation_39[0][0]']
#
#  activation_40 (Activation)     (None, 56, 56, 64)   0           ['add_12[0][0]']
#
#  res_s2_b3_branch_a (Conv2D)    (None, 56, 56, 64)   36928       ['activation_40[0][0]']
#
#  bn_s2_b3_branch_a (BatchNormal  (None, 56, 56, 64)  256         ['res_s2_b3_branch_a[0][0]']
#  ization)
#
#  activation_41 (Activation)     (None, 56, 56, 64)   0           ['bn_s2_b3_branch_a[0][0]']
#
#  res_s2_b3_branch_b (Conv2D)    (None, 56, 56, 64)   36928       ['activation_41[0][0]']
#
#  bn_s2_b3_branch_b (BatchNormal  (None, 56, 56, 64)  256         ['res_s2_b3_branch_b[0][0]']
#  ization)
#
#  activation_42 (Activation)     (None, 56, 56, 64)   0           ['bn_s2_b3_branch_b[0][0]']
#
#  add_13 (Add)                   (None, 56, 56, 64)   0           ['activation_40[0][0]',
#                                                                   'activation_42[0][0]']
#
#  activation_43 (Activation)     (None, 56, 56, 64)   0           ['add_13[0][0]']
#
#  res_s3_b1_branch_padding (Zero  (None, 58, 58, 64)  0           ['activation_43[0][0]']
#  Padding2D)
#
#  res_s3_b1_branch_a (Conv2D)    (None, 28, 28, 128)  73856       ['res_s3_b1_branch_padding[0][0]'
#                                                                  ]
#
#  bn_s3_b1_branch_a (BatchNormal  (None, 28, 28, 128)  512        ['res_s3_b1_branch_a[0][0]']
#  ization)
#
#  activation_44 (Activation)     (None, 28, 28, 128)  0           ['bn_s3_b1_branch_a[0][0]']
#
#  res_s3_b1_branch_b (Conv2D)    (None, 28, 28, 128)  147584      ['activation_44[0][0]']
#
#  bn_s3_b1_branch_b (BatchNormal  (None, 28, 28, 128)  512        ['res_s3_b1_branch_b[0][0]']
#  ization)
#
#  activation_45 (Activation)     (None, 28, 28, 128)  0           ['bn_s3_b1_branch_b[0][0]']
#
#  res_s3_b2_branch_a (Conv2D)    (None, 28, 28, 128)  147584      ['activation_45[0][0]']
#
#  bn_s3_b2_branch_a (BatchNormal  (None, 28, 28, 128)  512        ['res_s3_b2_branch_a[0][0]']
#  ization)
#
#  activation_46 (Activation)     (None, 28, 28, 128)  0           ['bn_s3_b2_branch_a[0][0]']
#
#  res_s3_b2_branch_b (Conv2D)    (None, 28, 28, 128)  147584      ['activation_46[0][0]']
#
#  bn_s3_b2_branch_b (BatchNormal  (None, 28, 28, 128)  512        ['res_s3_b2_branch_b[0][0]']
#  ization)
#
#  activation_47 (Activation)     (None, 28, 28, 128)  0           ['bn_s3_b2_branch_b[0][0]']
#
#  add_15 (Add)                   (None, 28, 28, 128)  0           ['activation_45[0][0]',
#                                                                   'activation_47[0][0]']
#
#  activation_48 (Activation)     (None, 28, 28, 128)  0           ['add_15[0][0]']
#
#  res_s3_b3_branch_a (Conv2D)    (None, 28, 28, 128)  147584      ['activation_48[0][0]']
#
#  bn_s3_b3_branch_a (BatchNormal  (None, 28, 28, 128)  512        ['res_s3_b3_branch_a[0][0]']
#  ization)
#
#  activation_49 (Activation)     (None, 28, 28, 128)  0           ['bn_s3_b3_branch_a[0][0]']
#
#  res_s3_b3_branch_b (Conv2D)    (None, 28, 28, 128)  147584      ['activation_49[0][0]']
#
#  bn_s3_b3_branch_b (BatchNormal  (None, 28, 28, 128)  512        ['res_s3_b3_branch_b[0][0]']
#  ization)
#
#  activation_50 (Activation)     (None, 28, 28, 128)  0           ['bn_s3_b3_branch_b[0][0]']
#
#  add_16 (Add)                   (None, 28, 28, 128)  0           ['activation_48[0][0]',
#                                                                   'activation_50[0][0]']
#
#  activation_51 (Activation)     (None, 28, 28, 128)  0           ['add_16[0][0]']
#
#  res_s3_b4_branch_a (Conv2D)    (None, 28, 28, 128)  147584      ['activation_51[0][0]']
#
#  bn_s3_b4_branch_a (BatchNormal  (None, 28, 28, 128)  512        ['res_s3_b4_branch_a[0][0]']
#  ization)
#
#  activation_52 (Activation)     (None, 28, 28, 128)  0           ['bn_s3_b4_branch_a[0][0]']
#
#  res_s3_b4_branch_b (Conv2D)    (None, 28, 28, 128)  147584      ['activation_52[0][0]']
#
#  bn_s3_b4_branch_b (BatchNormal  (None, 28, 28, 128)  512        ['res_s3_b4_branch_b[0][0]']
#  ization)
#
#  activation_53 (Activation)     (None, 28, 28, 128)  0           ['bn_s3_b4_branch_b[0][0]']
#
#  add_17 (Add)                   (None, 28, 28, 128)  0           ['activation_51[0][0]',
#                                                                   'activation_53[0][0]']
#
#  activation_54 (Activation)     (None, 28, 28, 128)  0           ['add_17[0][0]']
#
#  res_s4_b1_branch_padding (Zero  (None, 30, 30, 128)  0          ['activation_54[0][0]']
#  Padding2D)
#
#  res_s4_b1_branch_a (Conv2D)    (None, 14, 14, 256)  295168      ['res_s4_b1_branch_padding[0][0]'
#                                                                  ]
#
#  bn_s4_b1_branch_a (BatchNormal  (None, 14, 14, 256)  1024       ['res_s4_b1_branch_a[0][0]']
#  ization)
#
#  activation_55 (Activation)     (None, 14, 14, 256)  0           ['bn_s4_b1_branch_a[0][0]']
#
#  res_s4_b1_branch_b (Conv2D)    (None, 14, 14, 256)  590080      ['activation_55[0][0]']
#
#  bn_s4_b1_branch_b (BatchNormal  (None, 14, 14, 256)  1024       ['res_s4_b1_branch_b[0][0]']
#  ization)
#
#  activation_56 (Activation)     (None, 14, 14, 256)  0           ['bn_s4_b1_branch_b[0][0]']
#
#  res_s4_b2_branch_a (Conv2D)    (None, 14, 14, 256)  590080      ['activation_56[0][0]']
#
#  bn_s4_b2_branch_a (BatchNormal  (None, 14, 14, 256)  1024       ['res_s4_b2_branch_a[0][0]']
#  ization)
#
#  activation_57 (Activation)     (None, 14, 14, 256)  0           ['bn_s4_b2_branch_a[0][0]']
#
#  res_s4_b2_branch_b (Conv2D)    (None, 14, 14, 256)  590080      ['activation_57[0][0]']
#
#  bn_s4_b2_branch_b (BatchNormal  (None, 14, 14, 256)  1024       ['res_s4_b2_branch_b[0][0]']
#  ization)
#
#  activation_58 (Activation)     (None, 14, 14, 256)  0           ['bn_s4_b2_branch_b[0][0]']
#
#  add_19 (Add)                   (None, 14, 14, 256)  0           ['activation_56[0][0]',
#                                                                   'activation_58[0][0]']
#
#  activation_59 (Activation)     (None, 14, 14, 256)  0           ['add_19[0][0]']
#
#  res_s4_b3_branch_a (Conv2D)    (None, 14, 14, 256)  590080      ['activation_59[0][0]']
#
#  bn_s4_b3_branch_a (BatchNormal  (None, 14, 14, 256)  1024       ['res_s4_b3_branch_a[0][0]']
#  ization)
#
#  activation_60 (Activation)     (None, 14, 14, 256)  0           ['bn_s4_b3_branch_a[0][0]']
#
#  res_s4_b3_branch_b (Conv2D)    (None, 14, 14, 256)  590080      ['activation_60[0][0]']
#
#  bn_s4_b3_branch_b (BatchNormal  (None, 14, 14, 256)  1024       ['res_s4_b3_branch_b[0][0]']
#  ization)
#
#  activation_61 (Activation)     (None, 14, 14, 256)  0           ['bn_s4_b3_branch_b[0][0]']
#
#  add_20 (Add)                   (None, 14, 14, 256)  0           ['activation_59[0][0]',
#                                                                   'activation_61[0][0]']
#
#  activation_62 (Activation)     (None, 14, 14, 256)  0           ['add_20[0][0]']
#
#  res_s4_b4_branch_a (Conv2D)    (None, 14, 14, 256)  590080      ['activation_62[0][0]']
#
#  bn_s4_b4_branch_a (BatchNormal  (None, 14, 14, 256)  1024       ['res_s4_b4_branch_a[0][0]']
#  ization)
#
#  activation_63 (Activation)     (None, 14, 14, 256)  0           ['bn_s4_b4_branch_a[0][0]']
#
#  res_s4_b4_branch_b (Conv2D)    (None, 14, 14, 256)  590080      ['activation_63[0][0]']
#
#  bn_s4_b4_branch_b (BatchNormal  (None, 14, 14, 256)  1024       ['res_s4_b4_branch_b[0][0]']
#  ization)
#
#  activation_64 (Activation)     (None, 14, 14, 256)  0           ['bn_s4_b4_branch_b[0][0]']
#
#  add_21 (Add)                   (None, 14, 14, 256)  0           ['activation_62[0][0]',
#                                                                   'activation_64[0][0]']
#
#  activation_65 (Activation)     (None, 14, 14, 256)  0           ['add_21[0][0]']
#
#  res_s4_b5_branch_a (Conv2D)    (None, 14, 14, 256)  590080      ['activation_65[0][0]']
#
#  bn_s4_b5_branch_a (BatchNormal  (None, 14, 14, 256)  1024       ['res_s4_b5_branch_a[0][0]']
#  ization)
#
#  activation_66 (Activation)     (None, 14, 14, 256)  0           ['bn_s4_b5_branch_a[0][0]']
#
#  res_s4_b5_branch_b (Conv2D)    (None, 14, 14, 256)  590080      ['activation_66[0][0]']
#
#  bn_s4_b5_branch_b (BatchNormal  (None, 14, 14, 256)  1024       ['res_s4_b5_branch_b[0][0]']
#  ization)
#
#  activation_67 (Activation)     (None, 14, 14, 256)  0           ['bn_s4_b5_branch_b[0][0]']
#
#  add_22 (Add)                   (None, 14, 14, 256)  0           ['activation_65[0][0]',
#                                                                   'activation_67[0][0]']
#
#  activation_68 (Activation)     (None, 14, 14, 256)  0           ['add_22[0][0]']
#
#  res_s4_b6_branch_a (Conv2D)    (None, 14, 14, 256)  590080      ['activation_68[0][0]']
#
#  bn_s4_b6_branch_a (BatchNormal  (None, 14, 14, 256)  1024       ['res_s4_b6_branch_a[0][0]']
#  ization)
#
#  activation_69 (Activation)     (None, 14, 14, 256)  0           ['bn_s4_b6_branch_a[0][0]']
#
#  res_s4_b6_branch_b (Conv2D)    (None, 14, 14, 256)  590080      ['activation_69[0][0]']
#
#  bn_s4_b6_branch_b (BatchNormal  (None, 14, 14, 256)  1024       ['res_s4_b6_branch_b[0][0]']
#  ization)
#
#  activation_70 (Activation)     (None, 14, 14, 256)  0           ['bn_s4_b6_branch_b[0][0]']
#
#  add_23 (Add)                   (None, 14, 14, 256)  0           ['activation_68[0][0]',
#                                                                   'activation_70[0][0]']
#
#  activation_71 (Activation)     (None, 14, 14, 256)  0           ['add_23[0][0]']
#
#  res_s5_b1_branch_padding (Zero  (None, 16, 16, 256)  0          ['activation_71[0][0]']
#  Padding2D)
#
#  res_s5_b1_branch_a (Conv2D)    (None, 7, 7, 512)    1180160     ['res_s5_b1_branch_padding[0][0]'
#                                                                  ]
#
#  bn_s5_b1_branch_a (BatchNormal  (None, 7, 7, 512)   2048        ['res_s5_b1_branch_a[0][0]']
#  ization)
#
#  activation_72 (Activation)     (None, 7, 7, 512)    0           ['bn_s5_b1_branch_a[0][0]']
#
#  res_s5_b1_branch_b (Conv2D)    (None, 7, 7, 512)    2359808     ['activation_72[0][0]']
#
#  bn_s5_b1_branch_b (BatchNormal  (None, 7, 7, 512)   2048        ['res_s5_b1_branch_b[0][0]']
#  ization)
#
#  activation_73 (Activation)     (None, 7, 7, 512)    0           ['bn_s5_b1_branch_b[0][0]']
#
#  res_s5_b2_branch_a (Conv2D)    (None, 7, 7, 512)    2359808     ['activation_73[0][0]']
#
#  bn_s5_b2_branch_a (BatchNormal  (None, 7, 7, 512)   2048        ['res_s5_b2_branch_a[0][0]']
#  ization)
#
#  activation_74 (Activation)     (None, 7, 7, 512)    0           ['bn_s5_b2_branch_a[0][0]']
#
#  res_s5_b2_branch_b (Conv2D)    (None, 7, 7, 512)    2359808     ['activation_74[0][0]']
#
#  bn_s5_b2_branch_b (BatchNormal  (None, 7, 7, 512)   2048        ['res_s5_b2_branch_b[0][0]']
#  ization)
#
#  activation_75 (Activation)     (None, 7, 7, 512)    0           ['bn_s5_b2_branch_b[0][0]']
#
#  add_25 (Add)                   (None, 7, 7, 512)    0           ['activation_73[0][0]',
#                                                                   'activation_75[0][0]']
#
#  activation_76 (Activation)     (None, 7, 7, 512)    0           ['add_25[0][0]']
#
#  res_s5_b3_branch_a (Conv2D)    (None, 7, 7, 512)    2359808     ['activation_76[0][0]']
#
#  bn_s5_b3_branch_a (BatchNormal  (None, 7, 7, 512)   2048        ['res_s5_b3_branch_a[0][0]']
#  ization)
#
#  activation_77 (Activation)     (None, 7, 7, 512)    0           ['bn_s5_b3_branch_a[0][0]']
#
#  res_s5_b3_branch_b (Conv2D)    (None, 7, 7, 512)    2359808     ['activation_77[0][0]']
#
#  bn_s5_b3_branch_b (BatchNormal  (None, 7, 7, 512)   2048        ['res_s5_b3_branch_b[0][0]']
#  ization)
#
#  activation_78 (Activation)     (None, 7, 7, 512)    0           ['bn_s5_b3_branch_b[0][0]']
#
#  add_26 (Add)                   (None, 7, 7, 512)    0           ['activation_76[0][0]',
#                                                                   'activation_78[0][0]']
#
#  activation_79 (Activation)     (None, 7, 7, 512)    0           ['add_26[0][0]']
#
#  GAP (GlobalAveragePooling2D)   (None, 512)          0           ['activation_79[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['GAP[0][0]']
#
#  fc1 (Dense)                    (None, 200)          102600      ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 200)          0           ['fc1[0][0]']
#
#  output (Dense)                 (None, 10)           2010        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 21,238,306
# Trainable params: 21,223,074
# Non-trainable params: 15,232
# __________________________________________________________________________________________________

# %% [markdown]
# ## ResNet50 구현하기

# %%
# resnet 구현
# cifar10 기준

def create_resnet_50(shape=(224,224,3)):
    input_tensor=Input(shape=shape)

    # 첫번째 stage.
    # Conv, pool
    x = first_conv(input_tensor)

    # 두번째 stage.
    x = reduce_block_50(x, middle_kernel_size=(3,3), filters=[64,64,256], stage=2, block=1, strides=(1,1))    
    x = identity_block_50(x, middle_kernel_size=(3,3), filters=[64,64,256], stage=2, block=2)
    x = identity_block_50(x, middle_kernel_size=(3,3), filters=[64,64,256], stage=2, block=3)

    # 세번째 stage
    x = reduce_block_50(x, middle_kernel_size=(3,3), filters=[128,128,512], stage=3, block=1, strides=(2,2))    
    x = identity_block_50(x, middle_kernel_size=(3,3), filters=[128,128,512], stage=3, block=2)
    x = identity_block_50(x, middle_kernel_size=(3,3), filters=[128,128,512], stage=3, block=3)
    x = identity_block_50(x, middle_kernel_size=(3,3), filters=[128,128,512], stage=3, block=4)

    # 네번째 stage
    x = reduce_block_50(x, middle_kernel_size=(3,3), filters=[256,256,1024], stage=4, block=1, strides=(2,2))    
    x = identity_block_50(x, middle_kernel_size=(3,3), filters=[256,256,1024], stage=4, block=2)
    x = identity_block_50(x, middle_kernel_size=(3,3), filters=[256,256,1024], stage=4, block=3)
    x = identity_block_50(x, middle_kernel_size=(3,3), filters=[256,256,1024], stage=4, block=4)
    x = identity_block_50(x, middle_kernel_size=(3,3), filters=[256,256,1024], stage=4, block=5)
    x = identity_block_50(x, middle_kernel_size=(3,3), filters=[256,256,1024], stage=4, block=6)

    # 다섯번째 stage
    x = reduce_block_50(x, middle_kernel_size=(3,3), filters=[512,512,2048], stage=5, block=1, strides=(2,2))
    x = identity_block_50(x, middle_kernel_size=(3,3), filters=[512,512,2048], stage=5, block=2)
    x = identity_block_50(x, middle_kernel_size=(3,3), filters=[512,512,2048], stage=5, block=3)


    # fc layer
    x = GlobalAveragePooling2D(name='GAP')(x)
    x = Dropout(rate=0.5)(x)
    x = Dense(200, activation='relu', name='fc_1')(x)
    x = Dropout(rate=0.5)(x)
    output = Dense(10, activation='softmax', name='output')(x)

    model = Model(inputs=input_tensor, outputs=output)
    model.summary()

    return model

# %%
model_50 = create_resnet_50(shape=(224,224,3))
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_2[0][0]']
#
#  conv1 (Conv2D)                 (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_nm (BatchNormalization)  (None, 112, 112, 64  256         ['conv1[0][0]']
#                                 )
#
#  activation_80 (Activation)     (None, 112, 112, 64  0           ['conv1_nm[0][0]']
#                                 )
#
#  pool1 (ZeroPadding2D)          (None, 114, 114, 64  0           ['activation_80[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 56, 56, 64)  0           ['pool1[0][0]']
#
#  res_s2_b1_branch_1 (Conv2D)    (None, 56, 56, 64)   4160        ['max_pooling2d_3[0][0]']
#
#  bn_s2_b1_branch_a (BatchNormal  (None, 56, 56, 64)  256         ['res_s2_b1_branch_1[0][0]']
#  ization)
#
#  activation_81 (Activation)     (None, 56, 56, 64)   0           ['bn_s2_b1_branch_a[0][0]']
#
#  res_s2_b1_branch_2 (Conv2D)    (None, 56, 56, 64)   36928       ['activation_81[0][0]']
#
#  bn_s2_b1_branch_b (BatchNormal  (None, 56, 56, 64)  256         ['res_s2_b1_branch_2[0][0]']
#  ization)
#
#  activation_82 (Activation)     (None, 56, 56, 64)   0           ['bn_s2_b1_branch_b[0][0]']
#
#  res_s2_b1_branch_3 (Conv2D)    (None, 56, 56, 256)  16640       ['activation_82[0][0]']
#
#  res_s2_b1_branch_shortcut (Con  (None, 56, 56, 256)  16640      ['max_pooling2d_3[0][0]']
#  v2D)
#
#  bn_s2_b1_branch_c (BatchNormal  (None, 56, 56, 256)  1024       ['res_s2_b1_branch_3[0][0]']
#  ization)
#
#  bn_s2_b1_branch_shortcut (Batc  (None, 56, 56, 256)  1024       ['res_s2_b1_branch_shortcut[0][0]
#  hNormalization)                                                 ']
#
#  add_27 (Add)                   (None, 56, 56, 256)  0           ['bn_s2_b1_branch_c[0][0]',
#                                                                   'bn_s2_b1_branch_shortcut[0][0]'
#                                                                  ]
#
#  activation_83 (Activation)     (None, 56, 56, 256)  0           ['add_27[0][0]']
#
#  res_s2_b2_branch_a (Conv2D)    (None, 56, 56, 64)   16448       ['activation_83[0][0]']
#
#  bn_s2_b2_branch_a (BatchNormal  (None, 56, 56, 64)  256         ['res_s2_b2_branch_a[0][0]']
#  ization)
#
#  activation_84 (Activation)     (None, 56, 56, 64)   0           ['bn_s2_b2_branch_a[0][0]']
#
#  res_s2_b2_branch_b (Conv2D)    (None, 56, 56, 64)   36928       ['activation_84[0][0]']
#
#  bn_s2_b2_branch_b (BatchNormal  (None, 56, 56, 64)  256         ['res_s2_b2_branch_b[0][0]']
#  ization)
#
#  activation_85 (Activation)     (None, 56, 56, 64)   0           ['bn_s2_b2_branch_b[0][0]']
#
#  res_s2_b2_branch_c (Conv2D)    (None, 56, 56, 256)  16640       ['activation_85[0][0]']
#
#  bn_s2_b2_branch_c (BatchNormal  (None, 56, 56, 256)  1024       ['res_s2_b2_branch_c[0][0]']
#  ization)
#
#  add_28 (Add)                   (None, 56, 56, 256)  0           ['activation_83[0][0]',
#                                                                   'bn_s2_b2_branch_c[0][0]']
#
#  activation_86 (Activation)     (None, 56, 56, 256)  0           ['add_28[0][0]']
#
#  res_s2_b3_branch_a (Conv2D)    (None, 56, 56, 64)   16448       ['activation_86[0][0]']
#
#  bn_s2_b3_branch_a (BatchNormal  (None, 56, 56, 64)  256         ['res_s2_b3_branch_a[0][0]']
#  ization)
#
#  activation_87 (Activation)     (None, 56, 56, 64)   0           ['bn_s2_b3_branch_a[0][0]']
#
#  res_s2_b3_branch_b (Conv2D)    (None, 56, 56, 64)   36928       ['activation_87[0][0]']
#
#  bn_s2_b3_branch_b (BatchNormal  (None, 56, 56, 64)  256         ['res_s2_b3_branch_b[0][0]']
#  ization)
#
#  activation_88 (Activation)     (None, 56, 56, 64)   0           ['bn_s2_b3_branch_b[0][0]']
#
#  res_s2_b3_branch_c (Conv2D)    (None, 56, 56, 256)  16640       ['activation_88[0][0]']
#
#  bn_s2_b3_branch_c (BatchNormal  (None, 56, 56, 256)  1024       ['res_s2_b3_branch_c[0][0]']
#  ization)
#
#  add_29 (Add)                   (None, 56, 56, 256)  0           ['activation_86[0][0]',
#                                                                   'bn_s2_b3_branch_c[0][0]']
#
#  activation_89 (Activation)     (None, 56, 56, 256)  0           ['add_29[0][0]']
#
#  res_s3_b1_branch_1 (Conv2D)    (None, 28, 28, 128)  32896       ['activation_89[0][0]']
#
#  bn_s3_b1_branch_a (BatchNormal  (None, 28, 28, 128)  512        ['res_s3_b1_branch_1[0][0]']
#  ization)
#
#  activation_90 (Activation)     (None, 28, 28, 128)  0           ['bn_s3_b1_branch_a[0][0]']
#
#  res_s3_b1_branch_2 (Conv2D)    (None, 28, 28, 128)  147584      ['activation_90[0][0]']
#
#  bn_s3_b1_branch_b (BatchNormal  (None, 28, 28, 128)  512        ['res_s3_b1_branch_2[0][0]']
#  ization)
#
#  activation_91 (Activation)     (None, 28, 28, 128)  0           ['bn_s3_b1_branch_b[0][0]']
#
#  res_s3_b1_branch_3 (Conv2D)    (None, 28, 28, 512)  66048       ['activation_91[0][0]']
#
#  res_s3_b1_branch_shortcut (Con  (None, 28, 28, 512)  131584     ['activation_89[0][0]']
#  v2D)
#
#  bn_s3_b1_branch_c (BatchNormal  (None, 28, 28, 512)  2048       ['res_s3_b1_branch_3[0][0]']
#  ization)
#
#  bn_s3_b1_branch_shortcut (Batc  (None, 28, 28, 512)  2048       ['res_s3_b1_branch_shortcut[0][0]
#  hNormalization)                                                 ']
#
#  add_30 (Add)                   (None, 28, 28, 512)  0           ['bn_s3_b1_branch_c[0][0]',
#                                                                   'bn_s3_b1_branch_shortcut[0][0]'
#                                                                  ]
#
#  activation_92 (Activation)     (None, 28, 28, 512)  0           ['add_30[0][0]']
#
#  res_s3_b2_branch_a (Conv2D)    (None, 28, 28, 128)  65664       ['activation_92[0][0]']
#
#  bn_s3_b2_branch_a (BatchNormal  (None, 28, 28, 128)  512        ['res_s3_b2_branch_a[0][0]']
#  ization)
#
#  activation_93 (Activation)     (None, 28, 28, 128)  0           ['bn_s3_b2_branch_a[0][0]']
#
#  res_s3_b2_branch_b (Conv2D)    (None, 28, 28, 128)  147584      ['activation_93[0][0]']
#
#  bn_s3_b2_branch_b (BatchNormal  (None, 28, 28, 128)  512        ['res_s3_b2_branch_b[0][0]']
#  ization)
#
#  activation_94 (Activation)     (None, 28, 28, 128)  0           ['bn_s3_b2_branch_b[0][0]']
#
#  res_s3_b2_branch_c (Conv2D)    (None, 28, 28, 512)  66048       ['activation_94[0][0]']
#
#  bn_s3_b2_branch_c (BatchNormal  (None, 28, 28, 512)  2048       ['res_s3_b2_branch_c[0][0]']
#  ization)
#
#  add_31 (Add)                   (None, 28, 28, 512)  0           ['activation_92[0][0]',
#                                                                   'bn_s3_b2_branch_c[0][0]']
#
#  activation_95 (Activation)     (None, 28, 28, 512)  0           ['add_31[0][0]']
#
#  res_s3_b3_branch_a (Conv2D)    (None, 28, 28, 128)  65664       ['activation_95[0][0]']
#
#  bn_s3_b3_branch_a (BatchNormal  (None, 28, 28, 128)  512        ['res_s3_b3_branch_a[0][0]']
#  ization)
#
#  activation_96 (Activation)     (None, 28, 28, 128)  0           ['bn_s3_b3_branch_a[0][0]']
#
#  res_s3_b3_branch_b (Conv2D)    (None, 28, 28, 128)  147584      ['activation_96[0][0]']
#
#  bn_s3_b3_branch_b (BatchNormal  (None, 28, 28, 128)  512        ['res_s3_b3_branch_b[0][0]']
#  ization)
#
#  activation_97 (Activation)     (None, 28, 28, 128)  0           ['bn_s3_b3_branch_b[0][0]']
#
#  res_s3_b3_branch_c (Conv2D)    (None, 28, 28, 512)  66048       ['activation_97[0][0]']
#
#  bn_s3_b3_branch_c (BatchNormal  (None, 28, 28, 512)  2048       ['res_s3_b3_branch_c[0][0]']
#  ization)
#
#  add_32 (Add)                   (None, 28, 28, 512)  0           ['activation_95[0][0]',
#                                                                   'bn_s3_b3_branch_c[0][0]']
#
#  activation_98 (Activation)     (None, 28, 28, 512)  0           ['add_32[0][0]']
#
#  res_s3_b4_branch_a (Conv2D)    (None, 28, 28, 128)  65664       ['activation_98[0][0]']
#
#  bn_s3_b4_branch_a (BatchNormal  (None, 28, 28, 128)  512        ['res_s3_b4_branch_a[0][0]']
#  ization)
#
#  activation_99 (Activation)     (None, 28, 28, 128)  0           ['bn_s3_b4_branch_a[0][0]']
#
#  res_s3_b4_branch_b (Conv2D)    (None, 28, 28, 128)  147584      ['activation_99[0][0]']
#
#  bn_s3_b4_branch_b (BatchNormal  (None, 28, 28, 128)  512        ['res_s3_b4_branch_b[0][0]']
#  ization)
#
#  activation_100 (Activation)    (None, 28, 28, 128)  0           ['bn_s3_b4_branch_b[0][0]']
#
#  res_s3_b4_branch_c (Conv2D)    (None, 28, 28, 512)  66048       ['activation_100[0][0]']
#
#  bn_s3_b4_branch_c (BatchNormal  (None, 28, 28, 512)  2048       ['res_s3_b4_branch_c[0][0]']
#  ization)
#
#  add_33 (Add)                   (None, 28, 28, 512)  0           ['activation_98[0][0]',
#                                                                   'bn_s3_b4_branch_c[0][0]']
#
#  activation_101 (Activation)    (None, 28, 28, 512)  0           ['add_33[0][0]']
#
#  res_s4_b1_branch_1 (Conv2D)    (None, 14, 14, 256)  131328      ['activation_101[0][0]']
#
#  bn_s4_b1_branch_a (BatchNormal  (None, 14, 14, 256)  1024       ['res_s4_b1_branch_1[0][0]']
#  ization)
#
#  activation_102 (Activation)    (None, 14, 14, 256)  0           ['bn_s4_b1_branch_a[0][0]']
#
#  res_s4_b1_branch_2 (Conv2D)    (None, 14, 14, 256)  590080      ['activation_102[0][0]']
#
#  bn_s4_b1_branch_b (BatchNormal  (None, 14, 14, 256)  1024       ['res_s4_b1_branch_2[0][0]']
#  ization)
#
#  activation_103 (Activation)    (None, 14, 14, 256)  0           ['bn_s4_b1_branch_b[0][0]']
#
#  res_s4_b1_branch_3 (Conv2D)    (None, 14, 14, 1024  263168      ['activation_103[0][0]']
#                                 )
#
#  res_s4_b1_branch_shortcut (Con  (None, 14, 14, 1024  525312     ['activation_101[0][0]']
#  v2D)                           )
#
#  bn_s4_b1_branch_c (BatchNormal  (None, 14, 14, 1024  4096       ['res_s4_b1_branch_3[0][0]']
#  ization)                       )
#
#  bn_s4_b1_branch_shortcut (Batc  (None, 14, 14, 1024  4096       ['res_s4_b1_branch_shortcut[0][0]
#  hNormalization)                )                                ']
#
#  add_34 (Add)                   (None, 14, 14, 1024  0           ['bn_s4_b1_branch_c[0][0]',
#                                 )                                 'bn_s4_b1_branch_shortcut[0][0]'
#                                                                  ]
#
#  activation_104 (Activation)    (None, 14, 14, 1024  0           ['add_34[0][0]']
#                                 )
#
#  res_s4_b2_branch_a (Conv2D)    (None, 14, 14, 256)  262400      ['activation_104[0][0]']
#
#  bn_s4_b2_branch_a (BatchNormal  (None, 14, 14, 256)  1024       ['res_s4_b2_branch_a[0][0]']
#  ization)
#
#  activation_105 (Activation)    (None, 14, 14, 256)  0           ['bn_s4_b2_branch_a[0][0]']
#
#  res_s4_b2_branch_b (Conv2D)    (None, 14, 14, 256)  590080      ['activation_105[0][0]']
#
#  bn_s4_b2_branch_b (BatchNormal  (None, 14, 14, 256)  1024       ['res_s4_b2_branch_b[0][0]']
#  ization)
#
#  activation_106 (Activation)    (None, 14, 14, 256)  0           ['bn_s4_b2_branch_b[0][0]']
#
#  res_s4_b2_branch_c (Conv2D)    (None, 14, 14, 1024  263168      ['activation_106[0][0]']
#                                 )
#
#  bn_s4_b2_branch_c (BatchNormal  (None, 14, 14, 1024  4096       ['res_s4_b2_branch_c[0][0]']
#  ization)                       )
#
#  add_35 (Add)                   (None, 14, 14, 1024  0           ['activation_104[0][0]',
#                                 )                                 'bn_s4_b2_branch_c[0][0]']
#
#  activation_107 (Activation)    (None, 14, 14, 1024  0           ['add_35[0][0]']
#                                 )
#
#  res_s4_b3_branch_a (Conv2D)    (None, 14, 14, 256)  262400      ['activation_107[0][0]']
#
#  bn_s4_b3_branch_a (BatchNormal  (None, 14, 14, 256)  1024       ['res_s4_b3_branch_a[0][0]']
#  ization)
#
#  activation_108 (Activation)    (None, 14, 14, 256)  0           ['bn_s4_b3_branch_a[0][0]']
#
#  res_s4_b3_branch_b (Conv2D)    (None, 14, 14, 256)  590080      ['activation_108[0][0]']
#
#  bn_s4_b3_branch_b (BatchNormal  (None, 14, 14, 256)  1024       ['res_s4_b3_branch_b[0][0]']
#  ization)
#
#  activation_109 (Activation)    (None, 14, 14, 256)  0           ['bn_s4_b3_branch_b[0][0]']
#
#  res_s4_b3_branch_c (Conv2D)    (None, 14, 14, 1024  263168      ['activation_109[0][0]']
#                                 )
#
#  bn_s4_b3_branch_c (BatchNormal  (None, 14, 14, 1024  4096       ['res_s4_b3_branch_c[0][0]']
#  ization)                       )
#
#  add_36 (Add)                   (None, 14, 14, 1024  0           ['activation_107[0][0]',
#                                 )                                 'bn_s4_b3_branch_c[0][0]']
#
#  activation_110 (Activation)    (None, 14, 14, 1024  0           ['add_36[0][0]']
#                                 )
#
#  res_s4_b4_branch_a (Conv2D)    (None, 14, 14, 256)  262400      ['activation_110[0][0]']
#
#  bn_s4_b4_branch_a (BatchNormal  (None, 14, 14, 256)  1024       ['res_s4_b4_branch_a[0][0]']
#  ization)
#
#  activation_111 (Activation)    (None, 14, 14, 256)  0           ['bn_s4_b4_branch_a[0][0]']
#
#  res_s4_b4_branch_b (Conv2D)    (None, 14, 14, 256)  590080      ['activation_111[0][0]']
#
#  bn_s4_b4_branch_b (BatchNormal  (None, 14, 14, 256)  1024       ['res_s4_b4_branch_b[0][0]']
#  ization)
#
#  activation_112 (Activation)    (None, 14, 14, 256)  0           ['bn_s4_b4_branch_b[0][0]']
#
#  res_s4_b4_branch_c (Conv2D)    (None, 14, 14, 1024  263168      ['activation_112[0][0]']
#                                 )
#
#  bn_s4_b4_branch_c (BatchNormal  (None, 14, 14, 1024  4096       ['res_s4_b4_branch_c[0][0]']
#  ization)                       )
#
#  add_37 (Add)                   (None, 14, 14, 1024  0           ['activation_110[0][0]',
#                                 )                                 'bn_s4_b4_branch_c[0][0]']
#
#  activation_113 (Activation)    (None, 14, 14, 1024  0           ['add_37[0][0]']
#                                 )
#
#  res_s4_b5_branch_a (Conv2D)    (None, 14, 14, 256)  262400      ['activation_113[0][0]']
#
#  bn_s4_b5_branch_a (BatchNormal  (None, 14, 14, 256)  1024       ['res_s4_b5_branch_a[0][0]']
#  ization)
#
#  activation_114 (Activation)    (None, 14, 14, 256)  0           ['bn_s4_b5_branch_a[0][0]']
#
#  res_s4_b5_branch_b (Conv2D)    (None, 14, 14, 256)  590080      ['activation_114[0][0]']
#
#  bn_s4_b5_branch_b (BatchNormal  (None, 14, 14, 256)  1024       ['res_s4_b5_branch_b[0][0]']
#  ization)
#
#  activation_115 (Activation)    (None, 14, 14, 256)  0           ['bn_s4_b5_branch_b[0][0]']
#
#  res_s4_b5_branch_c (Conv2D)    (None, 14, 14, 1024  263168      ['activation_115[0][0]']
#                                 )
#
#  bn_s4_b5_branch_c (BatchNormal  (None, 14, 14, 1024  4096       ['res_s4_b5_branch_c[0][0]']
#  ization)                       )
#
#  add_38 (Add)                   (None, 14, 14, 1024  0           ['activation_113[0][0]',
#                                 )                                 'bn_s4_b5_branch_c[0][0]']
#
#  activation_116 (Activation)    (None, 14, 14, 1024  0           ['add_38[0][0]']
#                                 )
#
#  res_s4_b6_branch_a (Conv2D)    (None, 14, 14, 256)  262400      ['activation_116[0][0]']
#
#  bn_s4_b6_branch_a (BatchNormal  (None, 14, 14, 256)  1024       ['res_s4_b6_branch_a[0][0]']
#  ization)
#
#  activation_117 (Activation)    (None, 14, 14, 256)  0           ['bn_s4_b6_branch_a[0][0]']
#
#  res_s4_b6_branch_b (Conv2D)    (None, 14, 14, 256)  590080      ['activation_117[0][0]']
#
#  bn_s4_b6_branch_b (BatchNormal  (None, 14, 14, 256)  1024       ['res_s4_b6_branch_b[0][0]']
#  ization)
#
#  activation_118 (Activation)    (None, 14, 14, 256)  0           ['bn_s4_b6_branch_b[0][0]']
#
#  res_s4_b6_branch_c (Conv2D)    (None, 14, 14, 1024  263168      ['activation_118[0][0]']
#                                 )
#
#  bn_s4_b6_branch_c (BatchNormal  (None, 14, 14, 1024  4096       ['res_s4_b6_branch_c[0][0]']
#  ization)                       )
#
#  add_39 (Add)                   (None, 14, 14, 1024  0           ['activation_116[0][0]',
#                                 )                                 'bn_s4_b6_branch_c[0][0]']
#
#  activation_119 (Activation)    (None, 14, 14, 1024  0           ['add_39[0][0]']
#                                 )
#
#  res_s5_b1_branch_1 (Conv2D)    (None, 7, 7, 512)    524800      ['activation_119[0][0]']
#
#  bn_s5_b1_branch_a (BatchNormal  (None, 7, 7, 512)   2048        ['res_s5_b1_branch_1[0][0]']
#  ization)
#
#  activation_120 (Activation)    (None, 7, 7, 512)    0           ['bn_s5_b1_branch_a[0][0]']
#
#  res_s5_b1_branch_2 (Conv2D)    (None, 7, 7, 512)    2359808     ['activation_120[0][0]']
#
#  bn_s5_b1_branch_b (BatchNormal  (None, 7, 7, 512)   2048        ['res_s5_b1_branch_2[0][0]']
#  ization)
#
#  activation_121 (Activation)    (None, 7, 7, 512)    0           ['bn_s5_b1_branch_b[0][0]']
#
#  res_s5_b1_branch_3 (Conv2D)    (None, 7, 7, 2048)   1050624     ['activation_121[0][0]']
#
#  res_s5_b1_branch_shortcut (Con  (None, 7, 7, 2048)  2099200     ['activation_119[0][0]']
#  v2D)
#
#  bn_s5_b1_branch_c (BatchNormal  (None, 7, 7, 2048)  8192        ['res_s5_b1_branch_3[0][0]']
#  ization)
#
#  bn_s5_b1_branch_shortcut (Batc  (None, 7, 7, 2048)  8192        ['res_s5_b1_branch_shortcut[0][0]
#  hNormalization)                                                 ']
#
#  add_40 (Add)                   (None, 7, 7, 2048)   0           ['bn_s5_b1_branch_c[0][0]',
#                                                                   'bn_s5_b1_branch_shortcut[0][0]'
#                                                                  ]
#
#  activation_122 (Activation)    (None, 7, 7, 2048)   0           ['add_40[0][0]']
#
#  res_s5_b2_branch_a (Conv2D)    (None, 7, 7, 512)    1049088     ['activation_122[0][0]']
#
#  bn_s5_b2_branch_a (BatchNormal  (None, 7, 7, 512)   2048        ['res_s5_b2_branch_a[0][0]']
#  ization)
#
#  activation_123 (Activation)    (None, 7, 7, 512)    0           ['bn_s5_b2_branch_a[0][0]']
#
#  res_s5_b2_branch_b (Conv2D)    (None, 7, 7, 512)    2359808     ['activation_123[0][0]']
#
#  bn_s5_b2_branch_b (BatchNormal  (None, 7, 7, 512)   2048        ['res_s5_b2_branch_b[0][0]']
#  ization)
#
#  activation_124 (Activation)    (None, 7, 7, 512)    0           ['bn_s5_b2_branch_b[0][0]']
#
#  res_s5_b2_branch_c (Conv2D)    (None, 7, 7, 2048)   1050624     ['activation_124[0][0]']
#
#  bn_s5_b2_branch_c (BatchNormal  (None, 7, 7, 2048)  8192        ['res_s5_b2_branch_c[0][0]']
#  ization)
#
#  add_41 (Add)                   (None, 7, 7, 2048)   0           ['activation_122[0][0]',
#                                                                   'bn_s5_b2_branch_c[0][0]']
#
#  activation_125 (Activation)    (None, 7, 7, 2048)   0           ['add_41[0][0]']
#
#  res_s5_b3_branch_a (Conv2D)    (None, 7, 7, 512)    1049088     ['activation_125[0][0]']
#
#  bn_s5_b3_branch_a (BatchNormal  (None, 7, 7, 512)   2048        ['res_s5_b3_branch_a[0][0]']
#  ization)
#
#  activation_126 (Activation)    (None, 7, 7, 512)    0           ['bn_s5_b3_branch_a[0][0]']
#
#  res_s5_b3_branch_b (Conv2D)    (None, 7, 7, 512)    2359808     ['activation_126[0][0]']
#
#  bn_s5_b3_branch_b (BatchNormal  (None, 7, 7, 512)   2048        ['res_s5_b3_branch_b[0][0]']
#  ization)
#
#  activation_127 (Activation)    (None, 7, 7, 512)    0           ['bn_s5_b3_branch_b[0][0]']
#
#  res_s5_b3_branch_c (Conv2D)    (None, 7, 7, 2048)   1050624     ['activation_127[0][0]']
#
#  bn_s5_b3_branch_c (BatchNormal  (None, 7, 7, 2048)  8192        ['res_s5_b3_branch_c[0][0]']
#  ization)
#
#  add_42 (Add)                   (None, 7, 7, 2048)   0           ['activation_125[0][0]',
#                                                                   'bn_s5_b3_branch_c[0][0]']
#
#  activation_128 (Activation)    (None, 7, 7, 2048)   0           ['add_42[0][0]']
#
#  GAP (GlobalAveragePooling2D)   (None, 2048)         0           ['activation_128[0][0]']
#
#  dropout_2 (Dropout)            (None, 2048)         0           ['GAP[0][0]']
#
#  fc_1 (Dense)                   (None, 200)          409800      ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 200)          0           ['fc_1[0][0]']
#
#  output (Dense)                 (None, 10)           2010        ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 23,999,522
# Trainable params: 23,946,402
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [markdown]
# ## Cifar10 데이터 셋 가져오기

# %%
IMAGE_SIZE = 128
BATCH_SIZE = 64



def get_preprocessed_ohe(images, labels, pre_func=None):
    if pre_func is not None:
        images = pre_func(labels)
    
    oh_labels = to_categorical(labels)
    return images, oh_labels

def get_train_valid_test_set(train_images, train_labels, test_images, test_labels, valid_size=0.5, random_state=2021):

    train_images, train_oh_labels = get_preprocessed_ohe(train_images, train_labels)
    test_images, test_oh_labels = get_preprocessed_ohe(test_images, test_labels)

    tr_images, val_images, tr_oh_labels, val_oh_labels = train_test_split(train_images, train_oh_labels, test_size=valid_size, random_state=2021)

    return (tr_images, tr_oh_labels), (val_images, val_oh_labels), (test_images, test_oh_labels)

class CIFAR_Dataset(Sequence):

    def __init__(self, images_array, labels, batch_size=BATCH_SIZE, augmentor=None, shuffle=False, pre_func=None):
        self.images_array = images_array
        self.labels = labels
        self.batch_size = batch_size
        self.augmentor = augmentor
        self.pre_func = pre_func
        self.shuffle = shuffle
        if self.shuffle:
            self.on_epoch_end()

    def __len__(self):
        
        return int(np.ceil(len(self.labels)/self.batch_size))


    def __getitem__(self, index):

        images_fetch = self.images_array[index*self.batch_size:(index+1)*self.batch_size]
        if self.labels is not None:
            label_batch = self.labels[index*self.batch_size:(index+1)*self.batch_size]
        
        image_batch = np.zeros((images_fetch.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3), dtype='float32')

        for image_index in range(images_fetch.shape[0]):
            image = cv2.resize(images_fetch[image_index], (IMAGE_SIZE, IMAGE_SIZE))

            if self.augmentor is not None:
                image = self.augmentor(image=image)['image']

            if self.pre_func is not None:
                image = self.pre_func(image)

            image_batch[image_index] = image

        return image_batch, label_batch

    def on_epoch_end(self):
        if(self.shuffle):
            self.images_array, self.labels = sklearn.utils.shuffle(self.images_array, self.labels)
        else:
            pass

# %%
# cifar10 데이터 가져오기

(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
print(train_images.shape, train_labels.shape, test_images.shape, test_labels.shape)

(tr_images, tr_oh_labels), (val_images, val_oh_labels), (test_image, test_oh_labels) = \
    get_train_valid_test_set(train_images, train_labels, test_images, test_labels, valid_size=0.5, random_state=2021)
print(tr_images.shape, tr_oh_labels.shape, val_images.shape, val_oh_labels.shape, test_images.shape, test_oh_labels.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step
# (50000, 32, 32, 3) (50000, 1) (10000, 32, 32, 3) (10000, 1)
# (25000, 32, 32, 3) (25000, 10) (25000, 32, 32, 3) (25000, 10) (10000, 32, 32, 3) (10000, 10)

# %%
# 학습용, 검증용 데이터셋 제너레이터 생성

from tensorflow.keras.applications.resnet50 import preprocess_input as resnet_preprocess

tr_ds = CIFAR_Dataset(tr_images, tr_oh_labels, batch_size = BATCH_SIZE, augmentor = None, shuffle = True, pre_func=resnet_preprocess)
val_ds = CIFAR_Dataset(val_images, val_oh_labels, batch_size=BATCH_SIZE, augmentor = None, shuffle = False, pre_func=resnet_preprocess)

print(next(iter(tr_ds))[0].shape, next(iter(val_ds))[0].shape)
print(next(iter(tr_ds))[1].shape, next(iter(val_ds))[1].shape)
# Out:
# (64, 128, 128, 3) (64, 128, 128, 3)
# (64, 10) (64, 10)

# %% [markdown]
# ## ResNet34를 이용한 모델 평가(cifar10)

# %%
from tensorflow.python.keras.callbacks import ReduceLROnPlateau, EarlyStopping
model_34 = create_resnet_34(shape=(128,128,3))

ely_stop = EarlyStopping(monitor = 'val_loss', patience=5, mode = 'min', verbose=1)

model_34.compile(optimizer = Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy']) 

history = model_34.fit(tr_ds, epochs=20, validation_data = val_ds,callbacks=[ely_stop])
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 134, 134, 3)  0           ['input_5[0][0]']
#
#  conv1 (Conv2D)                 (None, 64, 64, 64)   9472        ['conv1_pad[0][0]']
#
#  conv1_nm (BatchNormalization)  (None, 64, 64, 64)   256         ['conv1[0][0]']
#
#  activation_221 (Activation)    (None, 64, 64, 64)   0           ['conv1_nm[0][0]']
#
#  pool1 (ZeroPadding2D)          (None, 66, 66, 64)   0           ['activation_221[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 64)  0           ['pool1[0][0]']
#
#  res_s2_b1_branch_a (Conv2D)    (None, 32, 32, 64)   36928       ['max_pooling2d_6[0][0]']
#
#  bn_s2_b1_branch_a (BatchNormal  (None, 32, 32, 64)  256         ['res_s2_b1_branch_a[0][0]']
#  ization)
#
#  activation_222 (Activation)    (None, 32, 32, 64)   0           ['bn_s2_b1_branch_a[0][0]']
#
#  res_s2_b1_branch_b (Conv2D)    (None, 32, 32, 64)   36928       ['activation_222[0][0]']
#
#  bn_s2_b1_branch_b (BatchNormal  (None, 32, 32, 64)  256         ['res_s2_b1_branch_b[0][0]']
#  ization)
#
#  activation_223 (Activation)    (None, 32, 32, 64)   0           ['bn_s2_b1_branch_b[0][0]']
#
#  add_75 (Add)                   (None, 32, 32, 64)   0           ['max_pooling2d_6[0][0]',
#                                                                   'activation_223[0][0]']
#
#  activation_224 (Activation)    (None, 32, 32, 64)   0           ['add_75[0][0]']
#
#  res_s2_b2_branch_a (Conv2D)    (None, 32, 32, 64)   36928       ['activation_224[0][0]']
#
#  bn_s2_b2_branch_a (BatchNormal  (None, 32, 32, 64)  256         ['res_s2_b2_branch_a[0][0]']
#  ization)
#
#  activation_225 (Activation)    (None, 32, 32, 64)   0           ['bn_s2_b2_branch_a[0][0]']
#
#  res_s2_b2_branch_b (Conv2D)    (None, 32, 32, 64)   36928       ['activation_225[0][0]']
#
#  bn_s2_b2_branch_b (BatchNormal  (None, 32, 32, 64)  256         ['res_s2_b2_branch_b[0][0]']
#  ization)
#
#  activation_226 (Activation)    (None, 32, 32, 64)   0           ['bn_s2_b2_branch_b[0][0]']
#
#  add_76 (Add)                   (None, 32, 32, 64)   0           ['activation_224[0][0]',
#                                                                   'activation_226[0][0]']
#
#  activation_227 (Activation)    (None, 32, 32, 64)   0           ['add_76[0][0]']
#
#  res_s2_b3_branch_a (Conv2D)    (None, 32, 32, 64)   36928       ['activation_227[0][0]']
#
#  bn_s2_b3_branch_a (BatchNormal  (None, 32, 32, 64)  256         ['res_s2_b3_branch_a[0][0]']
#  ization)
#
#  activation_228 (Activation)    (None, 32, 32, 64)   0           ['bn_s2_b3_branch_a[0][0]']
#
#  res_s2_b3_branch_b (Conv2D)    (None, 32, 32, 64)   36928       ['activation_228[0][0]']
#
#  bn_s2_b3_branch_b (BatchNormal  (None, 32, 32, 64)  256         ['res_s2_b3_branch_b[0][0]']
#  ization)
#
#  activation_229 (Activation)    (None, 32, 32, 64)   0           ['bn_s2_b3_branch_b[0][0]']
#
#  add_77 (Add)                   (None, 32, 32, 64)   0           ['activation_227[0][0]',
#                                                                   'activation_229[0][0]']
#
#  activation_230 (Activation)    (None, 32, 32, 64)   0           ['add_77[0][0]']
#
#  res_s3_b1_branch_padding (Zero  (None, 34, 34, 64)  0           ['activation_230[0][0]']
#  Padding2D)
#
#  res_s3_b1_branch_a (Conv2D)    (None, 16, 16, 128)  73856       ['res_s3_b1_branch_padding[0][0]'
#                                                                  ]
#
#  bn_s3_b1_branch_a (BatchNormal  (None, 16, 16, 128)  512        ['res_s3_b1_branch_a[0][0]']
#  ization)
#
#  activation_231 (Activation)    (None, 16, 16, 128)  0           ['bn_s3_b1_branch_a[0][0]']
#
#  res_s3_b1_branch_b (Conv2D)    (None, 16, 16, 128)  147584      ['activation_231[0][0]']
#
#  bn_s3_b1_branch_b (BatchNormal  (None, 16, 16, 128)  512        ['res_s3_b1_branch_b[0][0]']
#  ization)
#
#  activation_232 (Activation)    (None, 16, 16, 128)  0           ['bn_s3_b1_branch_b[0][0]']
#
#  res_s3_b2_branch_a (Conv2D)    (None, 16, 16, 128)  147584      ['activation_232[0][0]']
#
#  bn_s3_b2_branch_a (BatchNormal  (None, 16, 16, 128)  512        ['res_s3_b2_branch_a[0][0]']
#  ization)
#
#  activation_233 (Activation)    (None, 16, 16, 128)  0           ['bn_s3_b2_branch_a[0][0]']
#
#  res_s3_b2_branch_b (Conv2D)    (None, 16, 16, 128)  147584      ['activation_233[0][0]']
#
#  bn_s3_b2_branch_b (BatchNormal  (None, 16, 16, 128)  512        ['res_s3_b2_branch_b[0][0]']
#  ization)
#
#  activation_234 (Activation)    (None, 16, 16, 128)  0           ['bn_s3_b2_branch_b[0][0]']
#
#  add_79 (Add)                   (None, 16, 16, 128)  0           ['activation_232[0][0]',
#                                                                   'activation_234[0][0]']
#
#  activation_235 (Activation)    (None, 16, 16, 128)  0           ['add_79[0][0]']
#
#  res_s3_b3_branch_a (Conv2D)    (None, 16, 16, 128)  147584      ['activation_235[0][0]']
#
#  bn_s3_b3_branch_a (BatchNormal  (None, 16, 16, 128)  512        ['res_s3_b3_branch_a[0][0]']
#  ization)
#
#  activation_236 (Activation)    (None, 16, 16, 128)  0           ['bn_s3_b3_branch_a[0][0]']
#
#  res_s3_b3_branch_b (Conv2D)    (None, 16, 16, 128)  147584      ['activation_236[0][0]']
#
#  bn_s3_b3_branch_b (BatchNormal  (None, 16, 16, 128)  512        ['res_s3_b3_branch_b[0][0]']
#  ization)
#
#  activation_237 (Activation)    (None, 16, 16, 128)  0           ['bn_s3_b3_branch_b[0][0]']
#
#  add_80 (Add)                   (None, 16, 16, 128)  0           ['activation_235[0][0]',
#                                                                   'activation_237[0][0]']
#
#  activation_238 (Activation)    (None, 16, 16, 128)  0           ['add_80[0][0]']
#
#  res_s3_b4_branch_a (Conv2D)    (None, 16, 16, 128)  147584      ['activation_238[0][0]']
#
#  bn_s3_b4_branch_a (BatchNormal  (None, 16, 16, 128)  512        ['res_s3_b4_branch_a[0][0]']
#  ization)
#
#  activation_239 (Activation)    (None, 16, 16, 128)  0           ['bn_s3_b4_branch_a[0][0]']
#
#  res_s3_b4_branch_b (Conv2D)    (None, 16, 16, 128)  147584      ['activation_239[0][0]']
#
#  bn_s3_b4_branch_b (BatchNormal  (None, 16, 16, 128)  512        ['res_s3_b4_branch_b[0][0]']
#  ization)
#
#  activation_240 (Activation)    (None, 16, 16, 128)  0           ['bn_s3_b4_branch_b[0][0]']
#
#  add_81 (Add)                   (None, 16, 16, 128)  0           ['activation_238[0][0]',
#                                                                   'activation_240[0][0]']
#
#  activation_241 (Activation)    (None, 16, 16, 128)  0           ['add_81[0][0]']
#
#  res_s4_b1_branch_padding (Zero  (None, 18, 18, 128)  0          ['activation_241[0][0]']
#  Padding2D)
#
#  res_s4_b1_branch_a (Conv2D)    (None, 8, 8, 256)    295168      ['res_s4_b1_branch_padding[0][0]'
#                                                                  ]
#
#  bn_s4_b1_branch_a (BatchNormal  (None, 8, 8, 256)   1024        ['res_s4_b1_branch_a[0][0]']
#  ization)
#
#  activation_242 (Activation)    (None, 8, 8, 256)    0           ['bn_s4_b1_branch_a[0][0]']
#
#  res_s4_b1_branch_b (Conv2D)    (None, 8, 8, 256)    590080      ['activation_242[0][0]']
#
#  bn_s4_b1_branch_b (BatchNormal  (None, 8, 8, 256)   1024        ['res_s4_b1_branch_b[0][0]']
#  ization)
#
#  activation_243 (Activation)    (None, 8, 8, 256)    0           ['bn_s4_b1_branch_b[0][0]']
#
#  res_s4_b2_branch_a (Conv2D)    (None, 8, 8, 256)    590080      ['activation_243[0][0]']
#
#  bn_s4_b2_branch_a (BatchNormal  (None, 8, 8, 256)   1024        ['res_s4_b2_branch_a[0][0]']
#  ization)
#
#  activation_244 (Activation)    (None, 8, 8, 256)    0           ['bn_s4_b2_branch_a[0][0]']
#
#  res_s4_b2_branch_b (Conv2D)    (None, 8, 8, 256)    590080      ['activation_244[0][0]']
#
#  bn_s4_b2_branch_b (BatchNormal  (None, 8, 8, 256)   1024        ['res_s4_b2_branch_b[0][0]']
#  ization)
#
#  activation_245 (Activation)    (None, 8, 8, 256)    0           ['bn_s4_b2_branch_b[0][0]']
#
#  add_83 (Add)                   (None, 8, 8, 256)    0           ['activation_243[0][0]',
#                                                                   'activation_245[0][0]']
#
#  activation_246 (Activation)    (None, 8, 8, 256)    0           ['add_83[0][0]']
#
#  res_s4_b3_branch_a (Conv2D)    (None, 8, 8, 256)    590080      ['activation_246[0][0]']
#
#  bn_s4_b3_branch_a (BatchNormal  (None, 8, 8, 256)   1024        ['res_s4_b3_branch_a[0][0]']
#  ization)
#
#  activation_247 (Activation)    (None, 8, 8, 256)    0           ['bn_s4_b3_branch_a[0][0]']
#
#  res_s4_b3_branch_b (Conv2D)    (None, 8, 8, 256)    590080      ['activation_247[0][0]']
#
#  bn_s4_b3_branch_b (BatchNormal  (None, 8, 8, 256)   1024        ['res_s4_b3_branch_b[0][0]']
#  ization)
#
#  activation_248 (Activation)    (None, 8, 8, 256)    0           ['bn_s4_b3_branch_b[0][0]']
#
#  add_84 (Add)                   (None, 8, 8, 256)    0           ['activation_246[0][0]',
#                                                                   'activation_248[0][0]']
#
#  activation_249 (Activation)    (None, 8, 8, 256)    0           ['add_84[0][0]']
#
#  res_s4_b4_branch_a (Conv2D)    (None, 8, 8, 256)    590080      ['activation_249[0][0]']
#
#  bn_s4_b4_branch_a (BatchNormal  (None, 8, 8, 256)   1024        ['res_s4_b4_branch_a[0][0]']
#  ization)
#
#  activation_250 (Activation)    (None, 8, 8, 256)    0           ['bn_s4_b4_branch_a[0][0]']
#
#  res_s4_b4_branch_b (Conv2D)    (None, 8, 8, 256)    590080      ['activation_250[0][0]']
#
#  bn_s4_b4_branch_b (BatchNormal  (None, 8, 8, 256)   1024        ['res_s4_b4_branch_b[0][0]']
#  ization)
#
#  activation_251 (Activation)    (None, 8, 8, 256)    0           ['bn_s4_b4_branch_b[0][0]']
#
#  add_85 (Add)                   (None, 8, 8, 256)    0           ['activation_249[0][0]',
#                                                                   'activation_251[0][0]']
#
#  activation_252 (Activation)    (None, 8, 8, 256)    0           ['add_85[0][0]']
#
#  res_s4_b5_branch_a (Conv2D)    (None, 8, 8, 256)    590080      ['activation_252[0][0]']
#
#  bn_s4_b5_branch_a (BatchNormal  (None, 8, 8, 256)   1024        ['res_s4_b5_branch_a[0][0]']
#  ization)
#
#  activation_253 (Activation)    (None, 8, 8, 256)    0           ['bn_s4_b5_branch_a[0][0]']
#
#  res_s4_b5_branch_b (Conv2D)    (None, 8, 8, 256)    590080      ['activation_253[0][0]']
#
#  bn_s4_b5_branch_b (BatchNormal  (None, 8, 8, 256)   1024        ['res_s4_b5_branch_b[0][0]']
#  ization)
#
#  activation_254 (Activation)    (None, 8, 8, 256)    0           ['bn_s4_b5_branch_b[0][0]']
#
#  add_86 (Add)                   (None, 8, 8, 256)    0           ['activation_252[0][0]',
#                                                                   'activation_254[0][0]']
#
#  activation_255 (Activation)    (None, 8, 8, 256)    0           ['add_86[0][0]']
#
#  res_s4_b6_branch_a (Conv2D)    (None, 8, 8, 256)    590080      ['activation_255[0][0]']
#
#  bn_s4_b6_branch_a (BatchNormal  (None, 8, 8, 256)   1024        ['res_s4_b6_branch_a[0][0]']
#  ization)
#
#  activation_256 (Activation)    (None, 8, 8, 256)    0           ['bn_s4_b6_branch_a[0][0]']
#
#  res_s4_b6_branch_b (Conv2D)    (None, 8, 8, 256)    590080      ['activation_256[0][0]']
#
#  bn_s4_b6_branch_b (BatchNormal  (None, 8, 8, 256)   1024        ['res_s4_b6_branch_b[0][0]']
#  ization)
#
#  activation_257 (Activation)    (None, 8, 8, 256)    0           ['bn_s4_b6_branch_b[0][0]']
#
#  add_87 (Add)                   (None, 8, 8, 256)    0           ['activation_255[0][0]',
#                                                                   'activation_257[0][0]']
#
#  activation_258 (Activation)    (None, 8, 8, 256)    0           ['add_87[0][0]']
#
#  res_s5_b1_branch_padding (Zero  (None, 10, 10, 256)  0          ['activation_258[0][0]']
#  Padding2D)
#
#  res_s5_b1_branch_a (Conv2D)    (None, 4, 4, 512)    1180160     ['res_s5_b1_branch_padding[0][0]'
#                                                                  ]
#
#  bn_s5_b1_branch_a (BatchNormal  (None, 4, 4, 512)   2048        ['res_s5_b1_branch_a[0][0]']
#  ization)
#
#  activation_259 (Activation)    (None, 4, 4, 512)    0           ['bn_s5_b1_branch_a[0][0]']
#
#  res_s5_b1_branch_b (Conv2D)    (None, 4, 4, 512)    2359808     ['activation_259[0][0]']
#
#  bn_s5_b1_branch_b (BatchNormal  (None, 4, 4, 512)   2048        ['res_s5_b1_branch_b[0][0]']
#  ization)
#
#  activation_260 (Activation)    (None, 4, 4, 512)    0           ['bn_s5_b1_branch_b[0][0]']
#
#  res_s5_b2_branch_a (Conv2D)    (None, 4, 4, 512)    2359808     ['activation_260[0][0]']
#
#  bn_s5_b2_branch_a (BatchNormal  (None, 4, 4, 512)   2048        ['res_s5_b2_branch_a[0][0]']
#  ization)
#
#  activation_261 (Activation)    (None, 4, 4, 512)    0           ['bn_s5_b2_branch_a[0][0]']
#
#  res_s5_b2_branch_b (Conv2D)    (None, 4, 4, 512)    2359808     ['activation_261[0][0]']
#
#  bn_s5_b2_branch_b (BatchNormal  (None, 4, 4, 512)   2048        ['res_s5_b2_branch_b[0][0]']
#  ization)
#
#  activation_262 (Activation)    (None, 4, 4, 512)    0           ['bn_s5_b2_branch_b[0][0]']
#
#  add_89 (Add)                   (None, 4, 4, 512)    0           ['activation_260[0][0]',
#                                                                   'activation_262[0][0]']
#
#  activation_263 (Activation)    (None, 4, 4, 512)    0           ['add_89[0][0]']
#
#  res_s5_b3_branch_a (Conv2D)    (None, 4, 4, 512)    2359808     ['activation_263[0][0]']
#
#  bn_s5_b3_branch_a (BatchNormal  (None, 4, 4, 512)   2048        ['res_s5_b3_branch_a[0][0]']
#  ization)
#
#  activation_264 (Activation)    (None, 4, 4, 512)    0           ['bn_s5_b3_branch_a[0][0]']
#
#  res_s5_b3_branch_b (Conv2D)    (None, 4, 4, 512)    2359808     ['activation_264[0][0]']
#
#  bn_s5_b3_branch_b (BatchNormal  (None, 4, 4, 512)   2048        ['res_s5_b3_branch_b[0][0]']
#  ization)
#
#  activation_265 (Activation)    (None, 4, 4, 512)    0           ['bn_s5_b3_branch_b[0][0]']
#
#  add_90 (Add)                   (None, 4, 4, 512)    0           ['activation_263[0][0]',
#                                                                   'activation_265[0][0]']
#
#  activation_266 (Activation)    (None, 4, 4, 512)    0           ['add_90[0][0]']
#
#  GAP (GlobalAveragePooling2D)   (None, 512)          0           ['activation_266[0][0]']
#
#  dropout_8 (Dropout)            (None, 512)          0           ['GAP[0][0]']
#
#  fc1 (Dense)                    (None, 200)          102600      ['dropout_8[0][0]']
#
#  dropout_9 (Dropout)            (None, 200)          0           ['fc1[0][0]']
#
#  output (Dense)                 (None, 10)           2010        ['dropout_9[0][0]']
#
# ==================================================================================================
# Total params: 21,238,306
# Trainable params: 21,223,074
# Non-trainable params: 15,232
# __________________________________________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/20
# 391/391 [==============================] - 176s 428ms/step - loss: 2.2420 - accuracy: 0.1796 - val_loss: 1.9407 - val_accuracy: 0.2614
# Epoch 2/20
# 391/391 [==============================] - 166s 424ms/step - loss: 1.7978 - accuracy: 0.2996 - val_loss: 2.2918 - val_accuracy: 0.2516
# Epoch 3/20
# 391/391 [==============================] - 166s 424ms/step - loss: 1.6323 - accuracy: 0.3818 - val_loss: 2.5104 - val_accuracy: 0.3280
# Epoch 4/20
# 391/391 [==============================] - 166s 425ms/step - loss: 1.4941 - accuracy: 0.4454 - val_loss: 1.3602 - val_accuracy: 0.5002
# Epoch 5/20
# 391/391 [==============================] - 166s 425ms/step - loss: 1.3496 - accuracy: 0.5150 - val_loss: 1.8216 - val_accuracy: 0.4170
# Epoch 6/20
# 391/391 [==============================] - 166s 425ms/step - loss: 1.2361 - accuracy: 0.5646 - val_loss: 1.3318 - val_accuracy: 0.5232
# Epoch 7/20
# 391/391 [==============================] - 166s 425ms/step - loss: 1.1397 - accuracy: 0.5995 - val_loss: 1.2095 - val_accuracy: 0.5928
# Epoch 8/20
# 391/391 [==============================] - 166s 425ms/step - loss: 1.0568 - accuracy: 0.6310 - val_loss: 5.5507 - val_accuracy: 0.4598
# Epoch 9/20
# 391/391 [==============================] - 166s 425ms/step - loss: 0.9672 - accuracy: 0.6609 - val_loss: 1.0513 - val_accuracy: 0.6456
# Epoch 10/20
# 391/391 [==============================] - 166s 425ms/step - loss: 0.9068 - accuracy: 0.6840 - val_loss: 0.9480 - val_accuracy: 0.6746
# Epoch 11/20
# 391/391 [==============================] - 166s 424ms/step - loss: 0.8470 - accuracy: 0.7086 - val_loss: 1.3580 - val_accuracy: 0.5809
# Epoch 12/20
# 391/391 [==============================] - 166s 425ms/step - loss: 0.7506 - accuracy: 0.7404 - val_loss: 1.0506 - val_accuracy: 0.6775
# Epoch 13/20
# 391/391 [==============================] - 166s 425ms/step - loss: 0.7049 - accuracy: 0.7616 - val_loss: 1.0188 - val_accuracy: 0.6726
# Epoch 14/20
# 391/391 [==============================] - 166s 425ms/step - loss: 0.6290 - accuracy: 0.7895 - val_loss: 0.7360 - val_accuracy: 0.7532
# Epoch 15/20
# 391/391 [==============================] - 166s 425ms/step - loss: 0.5801 - accuracy: 0.8026 - val_loss: 0.8288 - val_accuracy: 0.7233
# Epoch 16/20
# 391/391 [==============================] - 166s 425ms/step - loss: 0.5980 - accuracy: 0.7980 - val_loss: 0.9968 - val_accuracy: 0.6903
# Epoch 17/20
# 391/391 [==============================] - 166s 425ms/step - loss: 0.5563 - accuracy: 0.8167 - val_loss: 0.8329 - val_accuracy: 0.7472
# Epoch 18/20
# 391/391 [==============================] - 166s 424ms/step - loss: 0.4407 - accuracy: 0.8523 - val_loss: 0.7608 - val_accuracy: 0.7674
# Epoch 19/20
# 391/391 [==============================] - 166s 424ms/step - loss: 0.3890 - accuracy: 0.8692 - val_loss: 1.4851 - val_accuracy: 0.6411
# Epoch 00019: early stopping

# %%
test_ds = CIFAR_Dataset(test_images, test_oh_labels, batch_size=BATCH_SIZE, augmentor=None, shuffle=False, pre_func=resnet_preprocess)
model_34.evaluate(test_ds)
# Out:
# 157/157 [==============================] - 20s 129ms/step - loss: 1.4701 - accuracy: 0.6388
# [1.470077395439148, 0.6388000249862671]

# %% [markdown]
# ## ResNet50을 이용한 모델 평가(cifar10)

# %%
model_50 = create_resnet_34(shape=(128,128,3))

ely_stop = EarlyStopping(monitor = 'val_loss', patience=5, mode = 'min', verbose=1)

model_50.compile(optimizer = Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy']) 

history = model_50.fit(tr_ds, epochs=20, validation_data = val_ds,callbacks=[ely_stop])
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 134, 134, 3)  0           ['input_6[0][0]']
#
#  conv1 (Conv2D)                 (None, 64, 64, 64)   9472        ['conv1_pad[0][0]']
#
#  conv1_nm (BatchNormalization)  (None, 64, 64, 64)   256         ['conv1[0][0]']
#
#  activation_267 (Activation)    (None, 64, 64, 64)   0           ['conv1_nm[0][0]']
#
#  pool1 (ZeroPadding2D)          (None, 66, 66, 64)   0           ['activation_267[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 64)  0           ['pool1[0][0]']
#
#  res_s2_b1_branch_a (Conv2D)    (None, 32, 32, 64)   36928       ['max_pooling2d_7[0][0]']
#
#  bn_s2_b1_branch_a (BatchNormal  (None, 32, 32, 64)  256         ['res_s2_b1_branch_a[0][0]']
#  ization)
#
#  activation_268 (Activation)    (None, 32, 32, 64)   0           ['bn_s2_b1_branch_a[0][0]']
#
#  res_s2_b1_branch_b (Conv2D)    (None, 32, 32, 64)   36928       ['activation_268[0][0]']
#
#  bn_s2_b1_branch_b (BatchNormal  (None, 32, 32, 64)  256         ['res_s2_b1_branch_b[0][0]']
#  ization)
#
#  activation_269 (Activation)    (None, 32, 32, 64)   0           ['bn_s2_b1_branch_b[0][0]']
#
#  add_91 (Add)                   (None, 32, 32, 64)   0           ['max_pooling2d_7[0][0]',
#                                                                   'activation_269[0][0]']
#
#  activation_270 (Activation)    (None, 32, 32, 64)   0           ['add_91[0][0]']
#
#  res_s2_b2_branch_a (Conv2D)    (None, 32, 32, 64)   36928       ['activation_270[0][0]']
#
#  bn_s2_b2_branch_a (BatchNormal  (None, 32, 32, 64)  256         ['res_s2_b2_branch_a[0][0]']
#  ization)
#
#  activation_271 (Activation)    (None, 32, 32, 64)   0           ['bn_s2_b2_branch_a[0][0]']
#
#  res_s2_b2_branch_b (Conv2D)    (None, 32, 32, 64)   36928       ['activation_271[0][0]']
#
#  bn_s2_b2_branch_b (BatchNormal  (None, 32, 32, 64)  256         ['res_s2_b2_branch_b[0][0]']
#  ization)
#
#  activation_272 (Activation)    (None, 32, 32, 64)   0           ['bn_s2_b2_branch_b[0][0]']
#
#  add_92 (Add)                   (None, 32, 32, 64)   0           ['activation_270[0][0]',
#                                                                   'activation_272[0][0]']
#
#  activation_273 (Activation)    (None, 32, 32, 64)   0           ['add_92[0][0]']
#
#  res_s2_b3_branch_a (Conv2D)    (None, 32, 32, 64)   36928       ['activation_273[0][0]']
#
#  bn_s2_b3_branch_a (BatchNormal  (None, 32, 32, 64)  256         ['res_s2_b3_branch_a[0][0]']
#  ization)
#
#  activation_274 (Activation)    (None, 32, 32, 64)   0           ['bn_s2_b3_branch_a[0][0]']
#
#  res_s2_b3_branch_b (Conv2D)    (None, 32, 32, 64)   36928       ['activation_274[0][0]']
#
#  bn_s2_b3_branch_b (BatchNormal  (None, 32, 32, 64)  256         ['res_s2_b3_branch_b[0][0]']
#  ization)
#
#  activation_275 (Activation)    (None, 32, 32, 64)   0           ['bn_s2_b3_branch_b[0][0]']
#
#  add_93 (Add)                   (None, 32, 32, 64)   0           ['activation_273[0][0]',
#                                                                   'activation_275[0][0]']
#
#  activation_276 (Activation)    (None, 32, 32, 64)   0           ['add_93[0][0]']
#
#  res_s3_b1_branch_padding (Zero  (None, 34, 34, 64)  0           ['activation_276[0][0]']
#  Padding2D)
#
#  res_s3_b1_branch_a (Conv2D)    (None, 16, 16, 128)  73856       ['res_s3_b1_branch_padding[0][0]'
#                                                                  ]
#
#  bn_s3_b1_branch_a (BatchNormal  (None, 16, 16, 128)  512        ['res_s3_b1_branch_a[0][0]']
#  ization)
#
#  activation_277 (Activation)    (None, 16, 16, 128)  0           ['bn_s3_b1_branch_a[0][0]']
#
#  res_s3_b1_branch_b (Conv2D)    (None, 16, 16, 128)  147584      ['activation_277[0][0]']
#
#  bn_s3_b1_branch_b (BatchNormal  (None, 16, 16, 128)  512        ['res_s3_b1_branch_b[0][0]']
#  ization)
#
#  activation_278 (Activation)    (None, 16, 16, 128)  0           ['bn_s3_b1_branch_b[0][0]']
#
#  res_s3_b2_branch_a (Conv2D)    (None, 16, 16, 128)  147584      ['activation_278[0][0]']
#
#  bn_s3_b2_branch_a (BatchNormal  (None, 16, 16, 128)  512        ['res_s3_b2_branch_a[0][0]']
#  ization)
#
#  activation_279 (Activation)    (None, 16, 16, 128)  0           ['bn_s3_b2_branch_a[0][0]']
#
#  res_s3_b2_branch_b (Conv2D)    (None, 16, 16, 128)  147584      ['activation_279[0][0]']
#
#  bn_s3_b2_branch_b (BatchNormal  (None, 16, 16, 128)  512        ['res_s3_b2_branch_b[0][0]']
#  ization)
#
#  activation_280 (Activation)    (None, 16, 16, 128)  0           ['bn_s3_b2_branch_b[0][0]']
#
#  add_95 (Add)                   (None, 16, 16, 128)  0           ['activation_278[0][0]',
#                                                                   'activation_280[0][0]']
#
#  activation_281 (Activation)    (None, 16, 16, 128)  0           ['add_95[0][0]']
#
#  res_s3_b3_branch_a (Conv2D)    (None, 16, 16, 128)  147584      ['activation_281[0][0]']
#
#  bn_s3_b3_branch_a (BatchNormal  (None, 16, 16, 128)  512        ['res_s3_b3_branch_a[0][0]']
#  ization)
#
#  activation_282 (Activation)    (None, 16, 16, 128)  0           ['bn_s3_b3_branch_a[0][0]']
#
#  res_s3_b3_branch_b (Conv2D)    (None, 16, 16, 128)  147584      ['activation_282[0][0]']
#
#  bn_s3_b3_branch_b (BatchNormal  (None, 16, 16, 128)  512        ['res_s3_b3_branch_b[0][0]']
#  ization)
#
#  activation_283 (Activation)    (None, 16, 16, 128)  0           ['bn_s3_b3_branch_b[0][0]']
#
#  add_96 (Add)                   (None, 16, 16, 128)  0           ['activation_281[0][0]',
#                                                                   'activation_283[0][0]']
#
#  activation_284 (Activation)    (None, 16, 16, 128)  0           ['add_96[0][0]']
#
#  res_s3_b4_branch_a (Conv2D)    (None, 16, 16, 128)  147584      ['activation_284[0][0]']
#
#  bn_s3_b4_branch_a (BatchNormal  (None, 16, 16, 128)  512        ['res_s3_b4_branch_a[0][0]']
#  ization)
#
#  activation_285 (Activation)    (None, 16, 16, 128)  0           ['bn_s3_b4_branch_a[0][0]']
#
#  res_s3_b4_branch_b (Conv2D)    (None, 16, 16, 128)  147584      ['activation_285[0][0]']
#
#  bn_s3_b4_branch_b (BatchNormal  (None, 16, 16, 128)  512        ['res_s3_b4_branch_b[0][0]']
#  ization)
#
#  activation_286 (Activation)    (None, 16, 16, 128)  0           ['bn_s3_b4_branch_b[0][0]']
#
#  add_97 (Add)                   (None, 16, 16, 128)  0           ['activation_284[0][0]',
#                                                                   'activation_286[0][0]']
#
#  activation_287 (Activation)    (None, 16, 16, 128)  0           ['add_97[0][0]']
#
#  res_s4_b1_branch_padding (Zero  (None, 18, 18, 128)  0          ['activation_287[0][0]']
#  Padding2D)
#
#  res_s4_b1_branch_a (Conv2D)    (None, 8, 8, 256)    295168      ['res_s4_b1_branch_padding[0][0]'
#                                                                  ]
#
#  bn_s4_b1_branch_a (BatchNormal  (None, 8, 8, 256)   1024        ['res_s4_b1_branch_a[0][0]']
#  ization)
#
#  activation_288 (Activation)    (None, 8, 8, 256)    0           ['bn_s4_b1_branch_a[0][0]']
#
#  res_s4_b1_branch_b (Conv2D)    (None, 8, 8, 256)    590080      ['activation_288[0][0]']
#
#  bn_s4_b1_branch_b (BatchNormal  (None, 8, 8, 256)   1024        ['res_s4_b1_branch_b[0][0]']
#  ization)
#
#  activation_289 (Activation)    (None, 8, 8, 256)    0           ['bn_s4_b1_branch_b[0][0]']
#
#  res_s4_b2_branch_a (Conv2D)    (None, 8, 8, 256)    590080      ['activation_289[0][0]']
#
#  bn_s4_b2_branch_a (BatchNormal  (None, 8, 8, 256)   1024        ['res_s4_b2_branch_a[0][0]']
#  ization)
#
#  activation_290 (Activation)    (None, 8, 8, 256)    0           ['bn_s4_b2_branch_a[0][0]']
#
#  res_s4_b2_branch_b (Conv2D)    (None, 8, 8, 256)    590080      ['activation_290[0][0]']
#
#  bn_s4_b2_branch_b (BatchNormal  (None, 8, 8, 256)   1024        ['res_s4_b2_branch_b[0][0]']
#  ization)
#
#  activation_291 (Activation)    (None, 8, 8, 256)    0           ['bn_s4_b2_branch_b[0][0]']
#
#  add_99 (Add)                   (None, 8, 8, 256)    0           ['activation_289[0][0]',
#                                                                   'activation_291[0][0]']
#
#  activation_292 (Activation)    (None, 8, 8, 256)    0           ['add_99[0][0]']
#
#  res_s4_b3_branch_a (Conv2D)    (None, 8, 8, 256)    590080      ['activation_292[0][0]']
#
#  bn_s4_b3_branch_a (BatchNormal  (None, 8, 8, 256)   1024        ['res_s4_b3_branch_a[0][0]']
#  ization)
#
#  activation_293 (Activation)    (None, 8, 8, 256)    0           ['bn_s4_b3_branch_a[0][0]']
#
#  res_s4_b3_branch_b (Conv2D)    (None, 8, 8, 256)    590080      ['activation_293[0][0]']
#
#  bn_s4_b3_branch_b (BatchNormal  (None, 8, 8, 256)   1024        ['res_s4_b3_branch_b[0][0]']
#  ization)
#
#  activation_294 (Activation)    (None, 8, 8, 256)    0           ['bn_s4_b3_branch_b[0][0]']
#
#  add_100 (Add)                  (None, 8, 8, 256)    0           ['activation_292[0][0]',
#                                                                   'activation_294[0][0]']
#
#  activation_295 (Activation)    (None, 8, 8, 256)    0           ['add_100[0][0]']
#
#  res_s4_b4_branch_a (Conv2D)    (None, 8, 8, 256)    590080      ['activation_295[0][0]']
#
#  bn_s4_b4_branch_a (BatchNormal  (None, 8, 8, 256)   1024        ['res_s4_b4_branch_a[0][0]']
#  ization)
#
#  activation_296 (Activation)    (None, 8, 8, 256)    0           ['bn_s4_b4_branch_a[0][0]']
#
#  res_s4_b4_branch_b (Conv2D)    (None, 8, 8, 256)    590080      ['activation_296[0][0]']
#
#  bn_s4_b4_branch_b (BatchNormal  (None, 8, 8, 256)   1024        ['res_s4_b4_branch_b[0][0]']
#  ization)
#
#  activation_297 (Activation)    (None, 8, 8, 256)    0           ['bn_s4_b4_branch_b[0][0]']
#
#  add_101 (Add)                  (None, 8, 8, 256)    0           ['activation_295[0][0]',
#                                                                   'activation_297[0][0]']
#
#  activation_298 (Activation)    (None, 8, 8, 256)    0           ['add_101[0][0]']
#
#  res_s4_b5_branch_a (Conv2D)    (None, 8, 8, 256)    590080      ['activation_298[0][0]']
#
#  bn_s4_b5_branch_a (BatchNormal  (None, 8, 8, 256)   1024        ['res_s4_b5_branch_a[0][0]']
#  ization)
#
#  activation_299 (Activation)    (None, 8, 8, 256)    0           ['bn_s4_b5_branch_a[0][0]']
#
#  res_s4_b5_branch_b (Conv2D)    (None, 8, 8, 256)    590080      ['activation_299[0][0]']
#
#  bn_s4_b5_branch_b (BatchNormal  (None, 8, 8, 256)   1024        ['res_s4_b5_branch_b[0][0]']
#  ization)
#
#  activation_300 (Activation)    (None, 8, 8, 256)    0           ['bn_s4_b5_branch_b[0][0]']
#
#  add_102 (Add)                  (None, 8, 8, 256)    0           ['activation_298[0][0]',
#                                                                   'activation_300[0][0]']
#
#  activation_301 (Activation)    (None, 8, 8, 256)    0           ['add_102[0][0]']
#
#  res_s4_b6_branch_a (Conv2D)    (None, 8, 8, 256)    590080      ['activation_301[0][0]']
#
#  bn_s4_b6_branch_a (BatchNormal  (None, 8, 8, 256)   1024        ['res_s4_b6_branch_a[0][0]']
#  ization)
#
#  activation_302 (Activation)    (None, 8, 8, 256)    0           ['bn_s4_b6_branch_a[0][0]']
#
#  res_s4_b6_branch_b (Conv2D)    (None, 8, 8, 256)    590080      ['activation_302[0][0]']
#
#  bn_s4_b6_branch_b (BatchNormal  (None, 8, 8, 256)   1024        ['res_s4_b6_branch_b[0][0]']
#  ization)
#
#  activation_303 (Activation)    (None, 8, 8, 256)    0           ['bn_s4_b6_branch_b[0][0]']
#
#  add_103 (Add)                  (None, 8, 8, 256)    0           ['activation_301[0][0]',
#                                                                   'activation_303[0][0]']
#
#  activation_304 (Activation)    (None, 8, 8, 256)    0           ['add_103[0][0]']
#
#  res_s5_b1_branch_padding (Zero  (None, 10, 10, 256)  0          ['activation_304[0][0]']
#  Padding2D)
#
#  res_s5_b1_branch_a (Conv2D)    (None, 4, 4, 512)    1180160     ['res_s5_b1_branch_padding[0][0]'
#                                                                  ]
#
#  bn_s5_b1_branch_a (BatchNormal  (None, 4, 4, 512)   2048        ['res_s5_b1_branch_a[0][0]']
#  ization)
#
#  activation_305 (Activation)    (None, 4, 4, 512)    0           ['bn_s5_b1_branch_a[0][0]']
#
#  res_s5_b1_branch_b (Conv2D)    (None, 4, 4, 512)    2359808     ['activation_305[0][0]']
#
#  bn_s5_b1_branch_b (BatchNormal  (None, 4, 4, 512)   2048        ['res_s5_b1_branch_b[0][0]']
#  ization)
#
#  activation_306 (Activation)    (None, 4, 4, 512)    0           ['bn_s5_b1_branch_b[0][0]']
#
#  res_s5_b2_branch_a (Conv2D)    (None, 4, 4, 512)    2359808     ['activation_306[0][0]']
#
#  bn_s5_b2_branch_a (BatchNormal  (None, 4, 4, 512)   2048        ['res_s5_b2_branch_a[0][0]']
#  ization)
#
#  activation_307 (Activation)    (None, 4, 4, 512)    0           ['bn_s5_b2_branch_a[0][0]']
#
#  res_s5_b2_branch_b (Conv2D)    (None, 4, 4, 512)    2359808     ['activation_307[0][0]']
#
#  bn_s5_b2_branch_b (BatchNormal  (None, 4, 4, 512)   2048        ['res_s5_b2_branch_b[0][0]']
#  ization)
#
#  activation_308 (Activation)    (None, 4, 4, 512)    0           ['bn_s5_b2_branch_b[0][0]']
#
#  add_105 (Add)                  (None, 4, 4, 512)    0           ['activation_306[0][0]',
#                                                                   'activation_308[0][0]']
#
#  activation_309 (Activation)    (None, 4, 4, 512)    0           ['add_105[0][0]']
#
#  res_s5_b3_branch_a (Conv2D)    (None, 4, 4, 512)    2359808     ['activation_309[0][0]']
#
#  bn_s5_b3_branch_a (BatchNormal  (None, 4, 4, 512)   2048        ['res_s5_b3_branch_a[0][0]']
#  ization)
#
#  activation_310 (Activation)    (None, 4, 4, 512)    0           ['bn_s5_b3_branch_a[0][0]']
#
#  res_s5_b3_branch_b (Conv2D)    (None, 4, 4, 512)    2359808     ['activation_310[0][0]']
#
#  bn_s5_b3_branch_b (BatchNormal  (None, 4, 4, 512)   2048        ['res_s5_b3_branch_b[0][0]']
#  ization)
#
#  activation_311 (Activation)    (None, 4, 4, 512)    0           ['bn_s5_b3_branch_b[0][0]']
#
#  add_106 (Add)                  (None, 4, 4, 512)    0           ['activation_309[0][0]',
#                                                                   'activation_311[0][0]']
#
#  activation_312 (Activation)    (None, 4, 4, 512)    0           ['add_106[0][0]']
#
#  GAP (GlobalAveragePooling2D)   (None, 512)          0           ['activation_312[0][0]']
#
#  dropout_10 (Dropout)           (None, 512)          0           ['GAP[0][0]']
#
#  fc1 (Dense)                    (None, 200)          102600      ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)           (None, 200)          0           ['fc1[0][0]']
#
#  output (Dense)                 (None, 10)           2010        ['dropout_11[0][0]']
#
# ==================================================================================================
# Total params: 21,238,306
# Trainable params: 21,223,074
# Non-trainable params: 15,232
# __________________________________________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/20
# 391/391 [==============================] - 174s 427ms/step - loss: 2.1850 - accuracy: 0.1929 - val_loss: 1.9224 - val_accuracy: 0.2463
# Epoch 2/20
# 391/391 [==============================] - 166s 425ms/step - loss: 1.7510 - accuracy: 0.3216 - val_loss: 1.7076 - val_accuracy: 0.3711
# Epoch 3/20
# 391/391 [==============================] - 166s 424ms/step - loss: 1.5332 - accuracy: 0.4261 - val_loss: 2.2016 - val_accuracy: 0.3436
# Epoch 4/20
# 391/391 [==============================] - 166s 425ms/step - loss: 1.3644 - accuracy: 0.5020 - val_loss: 1.2949 - val_accuracy: 0.5232
# Epoch 5/20
# 391/391 [==============================] - 166s 425ms/step - loss: 1.2251 - accuracy: 0.5620 - val_loss: 1.7635 - val_accuracy: 0.4375
# Epoch 6/20
# 391/391 [==============================] - 166s 425ms/step - loss: 1.1425 - accuracy: 0.5983 - val_loss: 1.6983 - val_accuracy: 0.4787
# Epoch 7/20
# 391/391 [==============================] - 166s 425ms/step - loss: 1.0712 - accuracy: 0.6236 - val_loss: 1.0487 - val_accuracy: 0.6239
# Epoch 8/20
# 391/391 [==============================] - 166s 425ms/step - loss: 0.9854 - accuracy: 0.6580 - val_loss: 1.4181 - val_accuracy: 0.5554
# Epoch 9/20
# 391/391 [==============================] - 166s 424ms/step - loss: 0.8638 - accuracy: 0.7014 - val_loss: 1.0738 - val_accuracy: 0.6604
# Epoch 10/20
# 391/391 [==============================] - 166s 424ms/step - loss: 0.7865 - accuracy: 0.7330 - val_loss: 1.3933 - val_accuracy: 0.6028
# Epoch 11/20
# 391/391 [==============================] - 166s 424ms/step - loss: 0.7063 - accuracy: 0.7646 - val_loss: 1.0109 - val_accuracy: 0.6672
# Epoch 12/20
# 391/391 [==============================] - 165s 423ms/step - loss: 0.6329 - accuracy: 0.7904 - val_loss: 0.9652 - val_accuracy: 0.6843
# Epoch 13/20
# 391/391 [==============================] - 166s 425ms/step - loss: 0.6041 - accuracy: 0.7993 - val_loss: 0.9990 - val_accuracy: 0.6748
# Epoch 14/20
# 391/391 [==============================] - 166s 424ms/step - loss: 0.5198 - accuracy: 0.8276 - val_loss: 1.1631 - val_accuracy: 0.6672
# Epoch 15/20
# 391/391 [==============================] - 166s 424ms/step - loss: 0.4442 - accuracy: 0.8543 - val_loss: 0.7007 - val_accuracy: 0.7716
# Epoch 16/20
# 391/391 [==============================] - 166s 424ms/step - loss: 0.3976 - accuracy: 0.8691 - val_loss: 1.3118 - val_accuracy: 0.6528
# Epoch 17/20
# 391/391 [==============================] - 165s 423ms/step - loss: 0.3385 - accuracy: 0.8870 - val_loss: 0.8863 - val_accuracy: 0.7594
# Epoch 18/20
# 391/391 [==============================] - 165s 423ms/step - loss: 0.2855 - accuracy: 0.9036 - val_loss: 0.8063 - val_accuracy: 0.7702
# Epoch 19/20
# 391/391 [==============================] - 166s 424ms/step - loss: 0.2590 - accuracy: 0.9148 - val_loss: 0.8682 - val_accuracy: 0.7606
# Epoch 20/20
# 391/391 [==============================] - 166s 424ms/step - loss: 0.2246 - accuracy: 0.9272 - val_loss: 0.8607 - val_accuracy: 0.7593
# Epoch 00020: early stopping

# %%
test_ds = CIFAR_Dataset(test_images, test_oh_labels, batch_size=BATCH_SIZE, augmentor=None, shuffle=False, pre_func=resnet_preprocess)
model_50.evaluate(test_ds)
# Out:
# 157/157 [==============================] - 20s 129ms/step - loss: 0.8664 - accuracy: 0.7573
# [0.8663582801818848, 0.7573000192642212]

# %% [markdown]
# ## 회고
#
# - 모델을 만들면서 주로 오류가 났던 부분은 shortcut과 residual block의 결과값을 합하는 부분이었다. stage2부터 shortcut으로 들어오는 inputdata의 채널값과 residual block의 결과값이 다른 경우가 있다. ex) input_data = (56,56,64), residual_ouput = (56,56,256). 이럴 경우, shortcut에 1x1 conv 연산을 통해 채널수를 256으로 늘려줘야 한다. CNN에서는 feature map의 사이즈를 계산하는 것이 중요하다는 것을 다시한번 깨닫는다.
#
# - 가장 허탈했던 오류는 'Shapes (None, None) and (None, 56, 56, 256) are incompatible'였다. 분명 모델 summary를 봤을 때는 문제가 없었는데 왜 계속 저 오류가 나오는지 몰라서 헤매다가 발견한 것이 모델변수명었다. 내가 만든 모델의 변수명은 model_34인데 model.fit으로 돌리고 있었으니 오류가 나는 것이었다. 변수명에 유의하자.
#
# - ResNet34와 ResNet50의 성능을 cifar10을 이용해 비교해 본 결과, layer가 더 깊은 50에서 좀 더 좋은 성능을 보였다. 시간관계상 이미지 사이즈를 128x128로 바꾸고 epoch를 20까지만 해서 돌렸다.
